# %% [markdown]
# https://en.wikipedia.org/wiki/Rank-maximal_allocation

# %% [markdown]
# # Installs

# %%
# !pip install scipy numpy pandas seaborn xlrd openpyxl
# %config Completer.use_jedi = False
# Out:
# Requirement already satisfied: scipy in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: numpy in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (1.24.3)
# Requirement already satisfied: pandas in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: seaborn in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: xlrd in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: openpyxl in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: et-xmlfile in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: six>=1.5 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/admin/.pyenv/versions/3.9.16/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the '/Users/admin/.pyenv/versions/3.9.16/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import scipy.optimize

import json

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 5]

import seaborn as sns
sns.set()

# %% [markdown]
# # Hungarian Algorithm

# %%
# Hungarian algorithm (Kuhn-Munkres) for solving the linear sum assignment
# problem. Taken from scikit-learn. Based on original code by Brian Clapper,
# adapted to NumPy by Gael Varoquaux.
# Further improvements by Ben Root, Vlad Niculae and Lars Buitinck.
#
# Copyright (c) 2008 Brian M. Clapper <bmc@clapper.org>, Gael Varoquaux
# Author: Brian M. Clapper, Gael Varoquaux
# License: 3-clause BSD

def linear_sum_assignment(cost_matrix):
    """Solve the linear sum assignment problem.

    The linear sum assignment problem is also known as minimum weight matching
    in bipartite graphs. A problem instance is described by a matrix C, where
    each C[i,j] is the cost of matching vertex i of the first partite set
    (a "worker") and vertex j of the second set (a "job"). The goal is to find
    a complete assignment of workers to jobs of minimal cost.

    Formally, let X be a boolean matrix where :math:`X[i,j] = 1` iff row i is
    assigned to column j. Then the optimal assignment has cost

    .. math::
        \min \sum_i \sum_j C_{i,j} X_{i,j}

    s.t. each row is assignment to at most one column, and each column to at
    most one row.

    This function can also solve a generalization of the classic assignment
    problem where the cost matrix is rectangular. If it has more rows than
    columns, then not every row needs to be assigned to a column, and vice
    versa.

    The method used is the Hungarian algorithm, also known as the Munkres or
    Kuhn-Munkres algorithm.

    Parameters
    ----------
    cost_matrix : array
        The cost matrix of the bipartite graph.

    Returns
    -------
    row_ind, col_ind : array
        An array of row indices and one of corresponding column indices giving
        the optimal assignment. The cost of the assignment can be computed
        as ``cost_matrix[row_ind, col_ind].sum()``. The row indices will be
        sorted; in the case of a square cost matrix they will be equal to
        ``numpy.arange(cost_matrix.shape[0])``.

    Notes
    -----
    .. versionadded:: 0.17.0

    Examples
    --------
    >>> cost = np.array([[4, 1, 3], [2, 0, 5], [3, 2, 2]])
    >>> from scipy.optimize import linear_sum_assignment
    >>> row_ind, col_ind = linear_sum_assignment(cost)
    >>> col_ind
    array([1, 0, 2])
    >>> cost[row_ind, col_ind].sum()
    5

    References
    ----------
    1. http://csclab.murraystate.edu/bob.pilgrim/445/munkres.html

    2. Harold W. Kuhn. The Hungarian Method for the assignment problem.
       *Naval Research Logistics Quarterly*, 2:83-97, 1955.

    3. Harold W. Kuhn. Variants of the Hungarian method for assignment
       problems. *Naval Research Logistics Quarterly*, 3: 253-258, 1956.

    4. Munkres, J. Algorithms for the Assignment and Transportation Problems.
       *J. SIAM*, 5(1):32-38, March, 1957.

    5. https://en.wikipedia.org/wiki/Hungarian_algorithm
    """
    cost_matrix = np.asarray(cost_matrix)
    if len(cost_matrix.shape) != 2:
        raise ValueError("expected a matrix (2-d array), got a %r array"
                         % (cost_matrix.shape,))

    # The algorithm expects more columns than rows in the cost matrix.
    if cost_matrix.shape[1] < cost_matrix.shape[0]:
        cost_matrix = cost_matrix.T
        transposed = True
    else:
        transposed = False

    state = _Hungary(cost_matrix)

    # No need to bother with assignments if one of the dimensions
    # of the cost matrix is zero-length.
    step = None if 0 in cost_matrix.shape else _step1

    while step is not None:
        step = step(state)

    if transposed:
        marked = state.marked.T
    else:
        marked = state.marked
    return np.where(marked == 1)


class _Hungary(object):
    """State of the Hungarian algorithm.

    Parameters
    ----------
    cost_matrix : 2D matrix
        The cost matrix. Must have shape[1] >= shape[0].
    """

    def __init__(self, cost_matrix):
        self.C = cost_matrix.copy()

        n, m = self.C.shape
        self.row_uncovered = np.ones(n, dtype=bool)
        self.col_uncovered = np.ones(m, dtype=bool)
        self.Z0_r = 0
        self.Z0_c = 0
        self.path = np.zeros((n + m, 2), dtype=int)
        self.marked = np.zeros((n, m), dtype=int)

    def _clear_covers(self):
        """Clear all covered matrix cells"""
        self.row_uncovered[:] = True
        self.col_uncovered[:] = True


# Individual steps of the algorithm follow, as a state machine: they return
# the next step to be taken (function to be called), if any.

def _step1(state):
    """Steps 1 and 2 in the Wikipedia page."""

    # Step 1: For each row of the matrix, find the smallest element and
    # subtract it from every element in its row.
    state.C -= state.C.min(axis=1)[:, np.newaxis]
    # Step 2: Find a zero (Z) in the resulting matrix. If there is no
    # starred zero in its row or column, star Z. Repeat for each element
    # in the matrix.
    for i, j in zip(*np.where(state.C == 0)):
        if state.col_uncovered[j] and state.row_uncovered[i]:
            state.marked[i, j] = 1
            state.col_uncovered[j] = False
            state.row_uncovered[i] = False

    state._clear_covers()
    return _step3


def _step3(state):
    """
    Cover each column containing a starred zero. If n columns are covered,
    the starred zeros describe a complete set of unique assignments.
    In this case, Go to DONE, otherwise, Go to Step 4.
    """
    marked = (state.marked == 1)
    state.col_uncovered[np.any(marked, axis=0)] = False

    if marked.sum() < state.C.shape[0]:
        return _step4


def _step4(state):
    """
    Find a noncovered zero and prime it. If there is no starred zero
    in the row containing this primed zero, Go to Step 5. Otherwise,
    cover this row and uncover the column containing the starred
    zero. Continue in this manner until there are no uncovered zeros
    left. Save the smallest uncovered value and Go to Step 6.
    """
    # We convert to int as numpy operations are faster on int
    C = (state.C == 0).astype(int)
    covered_C = C * state.row_uncovered[:, np.newaxis]
    covered_C *= np.asarray(state.col_uncovered, dtype=int)
    n = state.C.shape[0]
    m = state.C.shape[1]

    while True:
        # Find an uncovered zero
        row, col = np.unravel_index(np.argmax(covered_C), (n, m))
        if covered_C[row, col] == 0:
            return _step6
        else:
            state.marked[row, col] = 2
            # Find the first starred element in the row
            star_col = np.argmax(state.marked[row] == 1)
            if state.marked[row, star_col] != 1:
                # Could not find one
                state.Z0_r = row
                state.Z0_c = col
                return _step5
            else:
                col = star_col
                state.row_uncovered[row] = False
                state.col_uncovered[col] = True
                covered_C[:, col] = C[:, col] * (
                    np.asarray(state.row_uncovered, dtype=int))
                covered_C[row] = 0


def _step5(state):
    """
    Construct a series of alternating primed and starred zeros as follows.
    Let Z0 represent the uncovered primed zero found in Step 4.
    Let Z1 denote the starred zero in the column of Z0 (if any).
    Let Z2 denote the primed zero in the row of Z1 (there will always be one).
    Continue until the series terminates at a primed zero that has no starred
    zero in its column. Unstar each starred zero of the series, star each
    primed zero of the series, erase all primes and uncover every line in the
    matrix. Return to Step 3
    """
    count = 0
    path = state.path
    path[count, 0] = state.Z0_r
    path[count, 1] = state.Z0_c

    while True:
        # Find the first starred element in the col defined by
        # the path.
        row = np.argmax(state.marked[:, path[count, 1]] == 1)
        if state.marked[row, path[count, 1]] != 1:
            # Could not find one
            break
        else:
            count += 1
            path[count, 0] = row
            path[count, 1] = path[count - 1, 1]

        # Find the first prime element in the row defined by the
        # first path step
        col = np.argmax(state.marked[path[count, 0]] == 2)
        if state.marked[row, col] != 2:
            col = -1
        count += 1
        path[count, 0] = path[count - 1, 0]
        path[count, 1] = col

    # Convert paths
    for i in range(count + 1):
        if state.marked[path[i, 0], path[i, 1]] == 1:
            state.marked[path[i, 0], path[i, 1]] = 0
        else:
            state.marked[path[i, 0], path[i, 1]] = 1

    state._clear_covers()
    # Erase all prime markings
    state.marked[state.marked == 2] = 0
    return _step3


def _step6(state):
    """
    Add the value found in Step 4 to every element of each covered row,
    and subtract it from every element of each uncovered column.
    Return to Step 4 without altering any stars, primes, or covered lines.
    """
    # the smallest uncovered value in the matrix
    if np.any(state.row_uncovered) and np.any(state.col_uncovered):
        minval = np.min(state.C[state.row_uncovered], axis=0)
        minval = np.min(minval[state.col_uncovered])
        state.C[~state.row_uncovered] += minval
        state.C[:, state.col_uncovered] -= minval
    return _step4

# %% [markdown]
# # Classes

# %% [markdown]
# We have $n$ applicants to $m$ jobs

# %%
class Profile:
    @staticmethod
    def compute_profile(ranks, applicants, jobs):
        """
        Returns the profile of a matching of applicants to jobs given the overall ranks.

            Parameters:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j
                applicants (np.ndarray): an n-vector of applicant indices
                jobs (np.ndarray): an m-vector of selected jobs corresponding to each applicant, so that jobs[i] is the choice of job for applicant[i]

            Returns:
                profile (np.ndarray): an m-vector where profile[i] is the number of applicants who were assigned their i'th pick of job
        """
        
        # applicants may be in an order different than [0, 1, 2, ...]
        selected_ranks = ranks[applicants]
        (n, m)  = selected_ranks.shape

        # Argsort turns an array of ranks into a list of jobs, ranked
        argsort = np.argsort(selected_ranks, axis=1)

        profile = np.zeros(m)

        for j in range(m):
            # Count how many jobs ranked 1st by applicants are equal to the jobs assigned.
            # Then, count how many jobs ranked 2nd were equal to the jobs assigned. etc.
            profile[j] = (argsort[:, j] == jobs).sum()

        # we should have assigned one job for each applicant.
        assert profile.sum() == n
        return profile
    
    @staticmethod
    def compare_profiles(a, b):
        """
        Used to compare profiles in lexicographic order.

            Parameters:
                a (np.ndarray): a profile for a matching. An m-vector where profile[i] is the number of applicants who were assigned their i'th pick of job
                b (np.ndarray): a profile for a matching.

            Returns:
                1  if b < a
                -1 if a < b
                0  if a = b
        """
        where = np.where( (a>b) != (a<b) )
        if where[0].size == 0:
            # they are identical
            return 0

        idx = where[0][0]

        if a[idx] < b[idx]:
            return -1
        elif a[idx] > b[idx]:
            return 1
        
    @staticmethod
    def compute_profile_from_result(ranks, matching):
        """
        Computes the profile from the output of the human-friendly algorithm.
        
            Parameters:
            Parameters:
                ranks (dict): a dictionary {[applicant]: {[job]: [ranking]}}
                matching (dict): a dictionary of {[applicant]: [job1, job2, ...]} of selected jobs.
                
            Returns:
                profile (np.ndarray): an m-vector where profile[i] is the number of applicants who were assigned their i'th pick of job
                
        """
        m = len(ranks[list(ranks.keys())[0]])
        profile = np.zeros(m, dtype=int)
        for applicant in ranks:
            for job in ranks[applicant]:
                rank = ranks[applicant][job]
                if job in matching[applicant]:
                    profile[rank] += 1
        assert profile.sum() == m
        return profile

# %%
class RankMaximalAllocation:
    @classmethod
    def generate_matching(cls, ranks):
        """
        Returns a tuple (applicants, jobs) corresponding to a bipartite graph matching between applicants and jobs.
        
            Parameters:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j
        
            Returns:
                applicants: a vector of length min(n, m) of the selected applicants. A vector of indices.
                jobs: a vector of length min(n, m) of the selected jobs. A vector of indices.
                
                The computed matching is essentially [(applicants[0], jobs[0]), applicants[1], jobs[1], ...]
                The retured format is more efficient for indexing operations.
        
        """
        weights = cls.compute_weights(ranks)
        applicants, jobs = linear_sum_assignment(weights)
        return applicants, jobs
    
    @staticmethod
    def compute_weights(ranks):
        """
        Returns a weight matrix the same shape as ranks. Used with linear sum assignment.
        
            Parameters:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j

            Returns:
                weights (np.ndarray): an n x m matrix of weights. Selecting at most one element from each row/column of this matrix should result in a minimum sum.
        
        Cited from Greedy Matchings by Robert W. Irving
        https://citeseerx.ist.psu.edu/viewdoc/download;jsessionid=0D4318167ED18A3CE8DF2FB5B2EA8321?doi=10.1.1.119.1747&rep=rep1&type=pdf
        
        > However, a greedy matching can be found by transforming to an instance of the classical
        > maximum weight bipartite matching problem. This involves allo cating a suitably steeply 
        > decreasing sequence of weights to the positions in each applicant's preference list to 
        > ensure that, for any value of i, an applicant who improves from his (i+1)th to his ith 
        > choice would change the weight of applicants who move down from their (i+j)th choice, 
        > for any value of j >= 1. This can be achieved, for example, by assigning a weight of 
        > n^(m-i) to each applicant's ith choice.
        """
        (n, m) = ranks.shape
        
        # we use object to take advantage of numpy's broadcasting
        # and python's unlimited integer representation
        weights = np.array(n, dtype=object)**(np.array(m, dtype=object)-ranks.astype(object))
        
        # negative because the Hungarian algorithm is trying to
        # minimize the costs, and weights are higher for a higher rank
        return -weights

# %%
class RoundRobin:
    @staticmethod
    def generate_matching(ranks):
        (n, m) = ranks.shape

        available_jobs = list(range(m))

        maximum_available_assignments = min(n, m)

        assigned_jobs = np.empty(maximum_available_assignments ,dtype=int)

        lottery_order = np.random.choice(np.arange(n), maximum_available_assignments, replace=False)
        for i in range(maximum_available_assignments):
            applicant = lottery_order[i]

            jobs = np.arange(m)
            ranks_for_applicant = ranks[applicant]

            # recall that ranks[i] is the *rank* for items 0, 1, 2, etc
            # so if we want to get the actual jobs they want in order, we
            # need to argsort
            jobs_in_preferred_order = jobs[np.argsort(ranks_for_applicant)]

            for j in jobs_in_preferred_order:
                if j in available_jobs:
                    available_jobs.remove(j)
                    assigned_jobs[i] = j

                    break
        return lottery_order, assigned_jobs

# %% [markdown]
# # Testing

# %%
class Test:
    def generate_random_ranks(n, m):
        """
        Create a random n x m matrix of rankings.
        
            Parameters:
                n (int): number of applicants
                m (int): number of jobs
            
            Returns:
                ranks (np.ndarray): an n x m matrix of rankings, where ranks[i,j] is the rank of applicant i for job j
        """
        ranks = np.array([np.random.permutation(m) for a in range(n)])
        return ranks
    
    @classmethod
    def compare_algorithms(cls, n, m, num_iterations, rounds):
        """
        Return a score between -1 and 1, with -1 being Round Robin wins every time and 1 being RMA wins every time.
        
            Parameters:
                n (int): number of applicants
                m (int): number of jobs
                num_iterations (int): how many random rankings to generate 
                rounds (int): the number of random round robin rounds to make per random ranking. Total iterations = num_iterations * rounds
            
            Returns:
                score (int): score from each trial averaged over all runs. Value is -1 if Round Robin produces a more optimal output, 1 if RMA produces a more optimal output, and 0 if they produce the same output.
        """
        scores = []
    
        for i in range(num_iterations):
            ranks = cls.generate_random_ranks(n, m)

            applicants_rm, jobs_rm = RankMaximalAllocation.generate_matching(ranks)
            profile_rm = Profile.compute_profile(ranks, applicants_rm, jobs_rm)

            for j in range(rounds):
                applicants_rr, jobs_rr = RoundRobin.generate_matching(ranks)
                profile_rr = Profile.compute_profile(ranks, applicants_rr, jobs_rr)

                score = Profile.compare_profiles(profile_rm, profile_rr)
                scores.append(score)

                # Below should never happen due to optimality of assignment
                if score == -1:
                    print(f'Found exception ({n},{m}) {profile_rr} > {profile_rm}')
                    print(f'ranks\t{ranks.tolist()}')
                    print(f'jobs_rm\t{jobs_rm.tolist()}')
                    print(f'jobs_rr\t{jobs_rr.tolist()}')
                    return

        return np.mean(scores)
    
    @classmethod
    def generate_comparison_plot(cls, N, M, num_iterations=10, rounds=10):
        scores = np.zeros((N, M))
        # TODO: Determine the problem with N=1 or M=1?
        for n in np.arange(2, N):
            for m in np.arange(2, M):
                print(f'n: {n} \tm: {m}     \r', end='')
                score = cls.compare_algorithms(n, m, num_iterations, rounds)
                scores[n, m] = score
        heatmap = sns.heatmap(scores, vmin=-1, vmax=1, cmap='coolwarm')
        _ = heatmap.set(xlabel=r'$m$', ylabel=r'$n$')
        return heatmap

# %%
# Test.generate_comparison_plot(30, 30)

# %% [markdown]
# # Matching

# %%
class MatchingGenerator:
    
    @staticmethod
    def generate_matching(rankings, strategy='RMA'):
        """
        
            Parameters:
                rankings (dict): a dictionary {[applicant]: {[job]: [ranking]}}
                strategy ('RMA' | 'RR'): the strategy. RMA for Rank-Maximal Allocation and RR for Round Robin
                
            Returns:
                matching (dict): a dictionary of {[applicant]: [job1, job2, ...]} of selected jobs.
        
        """
        
        # general strategy: convert rankings to a ranking matrix, using inverse indices to convert back
        # given n applicants and m jobs, both strategies return min(n, m) assignments.
        # therefore, if we want to allow applicants to receive multiple jobs, we basically give everyone
        # their top choice first, and then remove the selected items from the pool, and run the process again.
        # we combine all of the results. 
        # in total, each person should receive at minimum floor(m/n) jobs.
        
        applicants = list(rankings.keys())
        applicants_mapping = {applicant: i for i, applicant in enumerate(applicants)}
        applicants_inverse_mapping = {i: applicant for i, applicant in enumerate(applicants)}

        jobs = []
        for applicant in applicants:
            applicant_jobs = rankings[applicant].keys()
            for job in applicant_jobs:
                jobs.append(job)
        jobs = list(set(jobs)) # get unique
        
        total_jobs = len(jobs)
        
        
        matching = {applicant: [] for applicant in applicants}
        while len(jobs) > 0:

            jobs_mapping = {job: j for j, job in enumerate(jobs)}
            jobs_inverse_mapping = {j: job for j, job in enumerate(jobs)}

            n = len(applicants)
            m = len(jobs)

            # default everything to be ranked last
            ranks = m * np.ones((n, m))
            for i in range(n):
                for j in range(m):
                    applicant_name = applicants_inverse_mapping[i]
                    job_name = jobs_inverse_mapping[j]

                    if job_name in rankings[applicant_name]:
                        rank = rankings[applicant_name][job_name]
                        ranks[i, j] = rank

            generate_matching = RankMaximalAllocation.generate_matching if strategy == 'RMA' else RoundRobin.generate_matching
            matched_applicants, matched_jobs = generate_matching(ranks)

            for applicant, job in zip(matched_applicants, matched_jobs):
                applicant_name = applicants_inverse_mapping[applicant]
                job_name = jobs_inverse_mapping[job]
                matching[applicant_name].append(job_name)
                
            for job in matched_jobs:
                job_name = jobs_inverse_mapping[job]
                jobs.remove(job_name)

        
        total_jobs_matched = sum(map(lambda x: len(x), matching.values()))
        assert total_jobs_matched == total_jobs, f'Expected total_jobs_matched to equal {total_jobs} but found {total_jobs_matched}'
        
        return matching

# %%
rankings = {
    'alice': {'x':1, 'y':2, 'z':3, 'a':4, 'b':5, 'c': 6, 'd':7},
    'bob':   {'x':3, 'y': 1, 'z':2, 'a':4,'b':5, 'c': 6},
    'jane':   {'x':3, 'y': 2, 'z':1, 'a':4, 'b':5, 'c': 6},
}
MatchingGenerator.generate_matching(rankings)
# Out:
# {'alice': ['x', 'a', 'c'], 'bob': ['y', 'd'], 'jane': ['z', 'b']}

# %%
rankings = {
    'alice': {'x':1, 'y':2, 'z':3},
    'bob':   {'x':3, 'y': 1, 'z':2},
    'jane':   {'x':3, 'y': 2, 'z':1},
    'joe':    {'x':1, 'y': 3, 'z':2}
}
MatchingGenerator.generate_matching(rankings)
# Out:
# {'alice': ['x'], 'bob': ['y'], 'jane': ['z'], 'joe': []}

# %% [markdown]
# # Parsing

# %%
import json

# %%
def normalize_rank_dict(data_dict):
    # Extract the values and create a NumPy array
    values_array = np.array(list(data_dict.values()))
    
    # Calculate the ranks using argsort and add 1 to start from rank 1
    ranks = np.argsort(values_array).argsort()
    
    # Create a new dictionary with ranked values
    ranked_dict = {key: rank for key, rank in zip(data_dict.keys(), ranks)}

    return ranked_dict

# %%
class PreferenceSheetParser:
    @staticmethod
    def generate_ranks(filename):
        xlsx = pd.ExcelFile(filename)
        rankings = {}

        total_quantity = xlsx.parse()['Quantity'].sum()
        minimum_rank = total_quantity - 1

        for sheet_name in xlsx.sheet_names:
            if sheet_name in ['Inventory', 'YourName', 'Info', 'Participants']:
                continue
            
            rankings[sheet_name] = {}

            df = pd.read_excel(xlsx, sheet_name)

            df.fillna(minimum_rank, inplace=True)
            
            
            # Normalize rankings so that they begin at 0 instead of 1 
            df['Preference'] -= df['Preference'].min()


            for index, row in df.iterrows():
                rank, qty, name = row['Preference'], row['Quantity'], row['Set Name']
                
                rankings[sheet_name][name] = rank

                # all duplicates will be ranked lower than non-duplicates
                # the relative ranking of duplicates will be preserved
                if qty > 1:
                    for duplicate in range(1, qty):
                        rankings[sheet_name][f'{name}_duplicate_{duplicate}'] = minimum_rank*duplicate + rank

            # normalize ranks
            rankings[sheet_name] = normalize_rank_dict(rankings[sheet_name])
        
        assert all(map(lambda e: len(e) == total_quantity, rankings.values()))
        return rankings

# %%
ranks = PreferenceSheetParser.generate_ranks('2023_Set_Draft.xlsx')
ranks
# Out:
# {'Black Six': {'Wildflower Bouquet': 0,
#   'Sunflowers': 1,
#   'Sunflowers_duplicate_1': 60,
#   'Sunflowers_duplicate_2': 75,
#   'Sunflowers_duplicate_3': 88,
#   'Sunflowers_duplicate_4': 101,
#   'Dark Trooper™ Attack': 2,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 3,
#   'Boba Fett’s Starship™': 4,
#   'Hoth™ AT-ST™': 5,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 6,
#   '007 Aston Martin DB5': 7,
#   'Fast & Furious 1970 Dodge Charger R/T': 8,
#   'Dragon of the East': 9,
#   'Evil Macaque’s Mech': 10,
#   'Ice-Cream Truck': 11,
#   'Heartlake City Pizzeria': 12,
#   'Heartlake City Pizzeria_duplicate_1': 61,
#   'Heartlake City Pizzeria_duplicate_2': 76,
#   'Heartlake City Pizzeria_duplicate_3': 89,
#   'Heartlake City Pizzeria_duplicate_4': 102,
#   'Pet Adoption Café': 13,
#   'Pony-Washing Stable': 14,
#   'Pony-Washing Stable_duplicate_1': 62,
#   'Pony-Washing Stable_duplicate_2': 77,
#   'Pony-Washing Stable_duplicate_3': 90,
#   'Pony-Washing Stable_duplicate_4': 103,
#   'Forest Waterfall': 15,
#   'Jasmine and Mulan’s Adventure': 16,
#   "Anna and Olaf's Castle Fun": 17,
#   'AT-ST™': 18,
#   'The "Abandoned" Mine': 19,
#   'The Ruined Portal': 20,
#   'The Nether Bastion': 21,
#   'Hogwarts™: Polyjuice Potion Mistake': 22,
#   'Hogwarts™ Magical Trunk': 23,
#   'Hogwarts™ Carriage and Thestrals': 24,
#   'Flower Bouquet': 25,
#   'Statue of Liberty': 26,
#   'Singapore': 27,
#   'Death Star™ Trench Run Diorama': 28,
#   'Creative Transparent Bricks': 57,
#   'Creative Transparent Bricks_duplicate_1': 67,
#   'Bricks and Functions': 59,
#   'Bricks and Functions_duplicate_1': 69,
#   'Creative Monkey Fun': 55,
#   'Creative Monkey Fun_duplicate_1': 66,
#   'Creative Monkey Fun_duplicate_2': 85,
#   'Creative Monkey Fun_duplicate_3': 97,
#   'Creative Monkey Fun_duplicate_4': 107,
#   'Sonic the Hedgehog™ – Green Hill Zone': 58,
#   'Cyber Drone': 56,
#   'Cyber Drone_duplicate_1': 73,
#   'Cyber Drone_duplicate_2': 84,
#   'Cyber Drone_duplicate_3': 96,
#   'Cyber Drone_duplicate_4': 106,
#   'Surfer Beach House': 53,
#   'Off-road Buggy': 52,
#   'Off-road Buggy_duplicate_1': 72,
#   'Off-road Buggy_duplicate_2': 86,
#   'Off-road Buggy_duplicate_3': 92,
#   'Off-road Buggy_duplicate_4': 112,
#   'Off-road Buggy_duplicate_5': 115,
#   'Off-road Buggy_duplicate_6': 117,
#   'Off-road Buggy_duplicate_7': 119,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 123,
#   'Super Robot': 37,
#   'Super Robot_duplicate_1': 63,
#   'Super Robot_duplicate_2': 83,
#   'Super Robot_duplicate_3': 95,
#   'Super Robot_duplicate_4': 108,
#   'Street Racer': 36,
#   'Majestic Tiger': 35,
#   'Adorable Dogs': 34,
#   'Cozy House': 33,
#   'Telehandler': 39,
#   'Telehandler_duplicate_1': 65,
#   'Telehandler_duplicate_2': 81,
#   'Telehandler_duplicate_3': 94,
#   'Telehandler_duplicate_4': 109,
#   'Material Handler': 32,
#   'Dump Truck': 31,
#   'Dump Truck_duplicate_1': 64,
#   'Dump Truck_duplicate_2': 79,
#   'Dump Truck_duplicate_3': 98,
#   'Dump Truck_duplicate_4': 110,
#   'Space Ride Amusement Truck': 30,
#   'Police Mobile Command Truck': 29,
#   'Police Chase at the Bank': 40,
#   'Wild Animal Rescue Missions': 41,
#   'Cyber Stunt Bike': 42,
#   'Cyber Stunt Bike_duplicate_1': 74,
#   'Cyber Stunt Bike_duplicate_2': 78,
#   'Cyber Stunt Bike_duplicate_3': 100,
#   'Cyber Stunt Bike_duplicate_4': 111,
#   'ATV and Otter Habitat': 43,
#   'ATV and Otter Habitat_duplicate_1': 71,
#   'ATV and Otter Habitat_duplicate_2': 80,
#   'ATV and Otter Habitat_duplicate_3': 91,
#   'ATV and Otter Habitat_duplicate_4': 113,
#   'ATV and Otter Habitat_duplicate_5': 114,
#   'ATV and Otter Habitat_duplicate_6': 116,
#   'ATV and Otter Habitat_duplicate_7': 118,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 122,
#   'Ninja Dragon Temple': 44,
#   'Lloyd’s Legendary Dragon': 45,
#   "Jay's Golden Dragon Motorbike": 46,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 70,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 82,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 99,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 105,
#   'Cole’s Dragon Cruiser': 47,
#   'Batmobile™: The Penguin™ Chase': 48,
#   "Shuri's Lab": 49,
#   "Shuri's Lab_duplicate_1": 68,
#   "Shuri's Lab_duplicate_2": 87,
#   "Shuri's Lab_duplicate_3": 93,
#   "Shuri's Lab_duplicate_4": 104,
#   'King Namor’s Throne Room': 50,
#   'Batman™ versus Harley Quinn™': 51,
#   'T. rex Dinosaur Breakout': 38,
#   'T. rex & Atrociraptor Dinosaur Breakout': 54},
#  'Primus': {'Flower Bouquet': 17,
#   'Wildflower Bouquet': 18,
#   'Creative Transparent Bricks': 48,
#   'Creative Transparent Bricks_duplicate_1': 69,
#   'Bricks and Functions': 47,
#   'Bricks and Functions_duplicate_1': 68,
#   'Creative Monkey Fun': 46,
#   'Creative Monkey Fun_duplicate_1': 67,
#   'Creative Monkey Fun_duplicate_2': 82,
#   'Creative Monkey Fun_duplicate_3': 95,
#   'Creative Monkey Fun_duplicate_4': 108,
#   'Statue of Liberty': 16,
#   'Singapore': 15,
#   'The "Abandoned" Mine': 49,
#   'The Ruined Portal': 50,
#   'The Nether Bastion': 51,
#   'Sonic the Hedgehog™ – Green Hill Zone': 14,
#   'Cyber Drone': 52,
#   'Cyber Drone_duplicate_1': 70,
#   'Cyber Drone_duplicate_2': 83,
#   'Cyber Drone_duplicate_3': 96,
#   'Cyber Drone_duplicate_4': 109,
#   'Surfer Beach House': 13,
#   'Off-road Buggy': 20,
#   'Off-road Buggy_duplicate_1': 60,
#   'Off-road Buggy_duplicate_2': 75,
#   'Off-road Buggy_duplicate_3': 88,
#   'Off-road Buggy_duplicate_4': 101,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 21,
#   'Super Robot_duplicate_1': 61,
#   'Super Robot_duplicate_2': 76,
#   'Super Robot_duplicate_3': 89,
#   'Super Robot_duplicate_4': 102,
#   'Street Racer': 22,
#   'Majestic Tiger': 12,
#   'Adorable Dogs': 24,
#   'Cozy House': 23,
#   'Sunflowers': 45,
#   'Sunflowers_duplicate_1': 66,
#   'Sunflowers_duplicate_2': 81,
#   'Sunflowers_duplicate_3': 94,
#   'Sunflowers_duplicate_4': 107,
#   'Forest Waterfall': 57,
#   'Pony-Washing Stable': 54,
#   'Pony-Washing Stable_duplicate_1': 71,
#   'Pony-Washing Stable_duplicate_2': 84,
#   'Pony-Washing Stable_duplicate_3': 97,
#   'Pony-Washing Stable_duplicate_4': 110,
#   'Pet Adoption Café': 55,
#   'Heartlake City Pizzeria': 56,
#   'Heartlake City Pizzeria_duplicate_1': 72,
#   'Heartlake City Pizzeria_duplicate_2': 85,
#   'Heartlake City Pizzeria_duplicate_3': 98,
#   'Heartlake City Pizzeria_duplicate_4': 111,
#   'Ice-Cream Truck': 53,
#   'Telehandler': 26,
#   'Telehandler_duplicate_1': 63,
#   'Telehandler_duplicate_2': 78,
#   'Telehandler_duplicate_3': 91,
#   'Telehandler_duplicate_4': 104,
#   'Material Handler': 10,
#   'Dump Truck': 25,
#   'Dump Truck_duplicate_1': 62,
#   'Dump Truck_duplicate_2': 77,
#   'Dump Truck_duplicate_3': 90,
#   'Dump Truck_duplicate_4': 103,
#   "Anna and Olaf's Castle Fun": 44,
#   'Jasmine and Mulan’s Adventure': 43,
#   'Space Ride Amusement Truck': 11,
#   'Police Mobile Command Truck': 19,
#   'Police Chase at the Bank': 28,
#   'Wild Animal Rescue Missions': 27,
#   'Cyber Stunt Bike': 59,
#   'Cyber Stunt Bike_duplicate_1': 74,
#   'Cyber Stunt Bike_duplicate_2': 87,
#   'Cyber Stunt Bike_duplicate_3': 100,
#   'Cyber Stunt Bike_duplicate_4': 113,
#   'ATV and Otter Habitat': 58,
#   'ATV and Otter Habitat_duplicate_1': 73,
#   'ATV and Otter Habitat_duplicate_2': 86,
#   'ATV and Otter Habitat_duplicate_3': 99,
#   'ATV and Otter Habitat_duplicate_4': 112,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 29,
#   'Lloyd’s Legendary Dragon': 9,
#   "Jay's Golden Dragon Motorbike": 30,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 64,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 79,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 92,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 105,
#   'Cole’s Dragon Cruiser': 8,
#   'Boba Fett’s Starship™': 6,
#   'Hoth™ AT-ST™': 7,
#   'Dark Trooper™ Attack': 31,
#   'Death Star™ Trench Run Diorama': 5,
#   'AT-ST™': 41,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 40,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 39,
#   'Batmobile™: The Penguin™ Chase': 34,
#   "Shuri's Lab": 32,
#   "Shuri's Lab_duplicate_1": 65,
#   "Shuri's Lab_duplicate_2": 80,
#   "Shuri's Lab_duplicate_3": 93,
#   "Shuri's Lab_duplicate_4": 106,
#   'King Namor’s Throne Room': 33,
#   'Batman™ versus Harley Quinn™': 42,
#   'Hogwarts™: Polyjuice Potion Mistake': 35,
#   'Hogwarts™ Magical Trunk': 4,
#   'Hogwarts™ Carriage and Thestrals': 36,
#   '007 Aston Martin DB5': 3,
#   'Fast & Furious 1970 Dodge Charger R/T': 2,
#   'T. rex Dinosaur Breakout': 37,
#   'T. rex & Atrociraptor Dinosaur Breakout': 38,
#   'Evil Macaque’s Mech': 1,
#   'Dragon of the East': 0},
#  'The Underscored Double': {'Flower Bouquet': 3,
#   'Wildflower Bouquet': 2,
#   'Creative Transparent Bricks': 47,
#   'Creative Transparent Bricks_duplicate_1': 67,
#   'Bricks and Functions': 48,
#   'Bricks and Functions_duplicate_1': 68,
#   'Creative Monkey Fun': 49,
#   'Creative Monkey Fun_duplicate_1': 69,
#   'Creative Monkey Fun_duplicate_2': 82,
#   'Creative Monkey Fun_duplicate_3': 95,
#   'Creative Monkey Fun_duplicate_4': 108,
#   'Statue of Liberty': 16,
#   'Singapore': 25,
#   'The "Abandoned" Mine': 24,
#   'The Ruined Portal': 23,
#   'The Nether Bastion': 22,
#   'Sonic the Hedgehog™ – Green Hill Zone': 15,
#   'Cyber Drone': 14,
#   'Cyber Drone_duplicate_1': 64,
#   'Cyber Drone_duplicate_2': 79,
#   'Cyber Drone_duplicate_3': 92,
#   'Cyber Drone_duplicate_4': 105,
#   'Surfer Beach House': 4,
#   'Off-road Buggy': 12,
#   'Off-road Buggy_duplicate_1': 63,
#   'Off-road Buggy_duplicate_2': 78,
#   'Off-road Buggy_duplicate_3': 91,
#   'Off-road Buggy_duplicate_4': 104,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 11,
#   'Super Robot_duplicate_1': 62,
#   'Super Robot_duplicate_2': 77,
#   'Super Robot_duplicate_3': 90,
#   'Super Robot_duplicate_4': 103,
#   'Street Racer': 13,
#   'Majestic Tiger': 5,
#   'Adorable Dogs': 20,
#   'Cozy House': 6,
#   'Sunflowers': 7,
#   'Sunflowers_duplicate_1': 60,
#   'Sunflowers_duplicate_2': 75,
#   'Sunflowers_duplicate_3': 88,
#   'Sunflowers_duplicate_4': 101,
#   'Forest Waterfall': 21,
#   'Pony-Washing Stable': 58,
#   'Pony-Washing Stable_duplicate_1': 73,
#   'Pony-Washing Stable_duplicate_2': 86,
#   'Pony-Washing Stable_duplicate_3': 99,
#   'Pony-Washing Stable_duplicate_4': 112,
#   'Pet Adoption Café': 40,
#   'Heartlake City Pizzeria': 59,
#   'Heartlake City Pizzeria_duplicate_1': 74,
#   'Heartlake City Pizzeria_duplicate_2': 87,
#   'Heartlake City Pizzeria_duplicate_3': 100,
#   'Heartlake City Pizzeria_duplicate_4': 113,
#   'Ice-Cream Truck': 52,
#   'Telehandler': 33,
#   'Telehandler_duplicate_1': 66,
#   'Telehandler_duplicate_2': 81,
#   'Telehandler_duplicate_3': 94,
#   'Telehandler_duplicate_4': 107,
#   'Material Handler': 17,
#   'Dump Truck': 32,
#   'Dump Truck_duplicate_1': 65,
#   'Dump Truck_duplicate_2': 80,
#   'Dump Truck_duplicate_3': 93,
#   'Dump Truck_duplicate_4': 106,
#   "Anna and Olaf's Castle Fun": 51,
#   'Jasmine and Mulan’s Adventure': 50,
#   'Space Ride Amusement Truck': 18,
#   'Police Mobile Command Truck': 35,
#   'Police Chase at the Bank': 36,
#   'Wild Animal Rescue Missions': 34,
#   'Cyber Stunt Bike': 57,
#   'Cyber Stunt Bike_duplicate_1': 72,
#   'Cyber Stunt Bike_duplicate_2': 85,
#   'Cyber Stunt Bike_duplicate_3': 98,
#   'Cyber Stunt Bike_duplicate_4': 111,
#   'ATV and Otter Habitat': 56,
#   'ATV and Otter Habitat_duplicate_1': 71,
#   'ATV and Otter Habitat_duplicate_2': 84,
#   'ATV and Otter Habitat_duplicate_3': 97,
#   'ATV and Otter Habitat_duplicate_4': 110,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 41,
#   'Lloyd’s Legendary Dragon': 1,
#   "Jay's Golden Dragon Motorbike": 9,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 61,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 76,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 89,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 102,
#   'Cole’s Dragon Cruiser': 8,
#   'Boba Fett’s Starship™': 19,
#   'Hoth™ AT-ST™': 26,
#   'Dark Trooper™ Attack': 27,
#   'Death Star™ Trench Run Diorama': 37,
#   'AT-ST™': 55,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 28,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 38,
#   'Batmobile™: The Penguin™ Chase': 39,
#   "Shuri's Lab": 53,
#   "Shuri's Lab_duplicate_1": 70,
#   "Shuri's Lab_duplicate_2": 83,
#   "Shuri's Lab_duplicate_3": 96,
#   "Shuri's Lab_duplicate_4": 109,
#   'King Namor’s Throne Room': 29,
#   'Batman™ versus Harley Quinn™': 54,
#   'Hogwarts™: Polyjuice Potion Mistake': 44,
#   'Hogwarts™ Magical Trunk': 42,
#   'Hogwarts™ Carriage and Thestrals': 43,
#   '007 Aston Martin DB5': 30,
#   'Fast & Furious 1970 Dodge Charger R/T': 31,
#   'T. rex Dinosaur Breakout': 46,
#   'T. rex & Atrociraptor Dinosaur Breakout': 45,
#   'Evil Macaque’s Mech': 10,
#   'Dragon of the East': 0},
#  'Thundra': {'Flower Bouquet': 21,
#   'Wildflower Bouquet': 0,
#   'Creative Transparent Bricks': 44,
#   'Creative Transparent Bricks_duplicate_1': 67,
#   'Bricks and Functions': 43,
#   'Bricks and Functions_duplicate_1': 66,
#   'Creative Monkey Fun': 42,
#   'Creative Monkey Fun_duplicate_1': 65,
#   'Creative Monkey Fun_duplicate_2': 80,
#   'Creative Monkey Fun_duplicate_3': 93,
#   'Creative Monkey Fun_duplicate_4': 106,
#   'Statue of Liberty': 9,
#   'Singapore': 5,
#   'The "Abandoned" Mine': 51,
#   'The Ruined Portal': 50,
#   'The Nether Bastion': 45,
#   'Sonic the Hedgehog™ – Green Hill Zone': 1,
#   'Cyber Drone': 56,
#   'Cyber Drone_duplicate_1': 73,
#   'Cyber Drone_duplicate_2': 86,
#   'Cyber Drone_duplicate_3': 99,
#   'Cyber Drone_duplicate_4': 112,
#   'Surfer Beach House': 36,
#   'Off-road Buggy': 48,
#   'Off-road Buggy_duplicate_1': 69,
#   'Off-road Buggy_duplicate_2': 82,
#   'Off-road Buggy_duplicate_3': 95,
#   'Off-road Buggy_duplicate_4': 108,
#   'Off-road Buggy_duplicate_5': 115,
#   'Off-road Buggy_duplicate_6': 117,
#   'Off-road Buggy_duplicate_7': 119,
#   'Off-road Buggy_duplicate_8': 121,
#   'Off-road Buggy_duplicate_9': 123,
#   'Super Robot': 8,
#   'Super Robot_duplicate_1': 60,
#   'Super Robot_duplicate_2': 75,
#   'Super Robot_duplicate_3': 88,
#   'Super Robot_duplicate_4': 101,
#   'Street Racer': 25,
#   'Majestic Tiger': 7,
#   'Adorable Dogs': 39,
#   'Cozy House': 20,
#   'Sunflowers': 26,
#   'Sunflowers_duplicate_1': 63,
#   'Sunflowers_duplicate_2': 78,
#   'Sunflowers_duplicate_3': 91,
#   'Sunflowers_duplicate_4': 104,
#   'Forest Waterfall': 41,
#   'Pony-Washing Stable': 59,
#   'Pony-Washing Stable_duplicate_1': 74,
#   'Pony-Washing Stable_duplicate_2': 87,
#   'Pony-Washing Stable_duplicate_3': 100,
#   'Pony-Washing Stable_duplicate_4': 113,
#   'Pet Adoption Café': 47,
#   'Heartlake City Pizzeria': 55,
#   'Heartlake City Pizzeria_duplicate_1': 72,
#   'Heartlake City Pizzeria_duplicate_2': 85,
#   'Heartlake City Pizzeria_duplicate_3': 98,
#   'Heartlake City Pizzeria_duplicate_4': 111,
#   'Ice-Cream Truck': 54,
#   'Telehandler': 53,
#   'Telehandler_duplicate_1': 71,
#   'Telehandler_duplicate_2': 84,
#   'Telehandler_duplicate_3': 97,
#   'Telehandler_duplicate_4': 110,
#   'Material Handler': 18,
#   'Dump Truck': 22,
#   'Dump Truck_duplicate_1': 62,
#   'Dump Truck_duplicate_2': 77,
#   'Dump Truck_duplicate_3': 90,
#   'Dump Truck_duplicate_4': 103,
#   "Anna and Olaf's Castle Fun": 57,
#   'Jasmine and Mulan’s Adventure': 58,
#   'Space Ride Amusement Truck': 12,
#   'Police Mobile Command Truck': 28,
#   'Police Chase at the Bank': 31,
#   'Wild Animal Rescue Missions': 13,
#   'Cyber Stunt Bike': 52,
#   'Cyber Stunt Bike_duplicate_1': 70,
#   'Cyber Stunt Bike_duplicate_2': 83,
#   'Cyber Stunt Bike_duplicate_3': 96,
#   'Cyber Stunt Bike_duplicate_4': 109,
#   'ATV and Otter Habitat': 40,
#   'ATV and Otter Habitat_duplicate_1': 64,
#   'ATV and Otter Habitat_duplicate_2': 79,
#   'ATV and Otter Habitat_duplicate_3': 92,
#   'ATV and Otter Habitat_duplicate_4': 105,
#   'ATV and Otter Habitat_duplicate_5': 114,
#   'ATV and Otter Habitat_duplicate_6': 116,
#   'ATV and Otter Habitat_duplicate_7': 118,
#   'ATV and Otter Habitat_duplicate_8': 120,
#   'ATV and Otter Habitat_duplicate_9': 122,
#   'Ninja Dragon Temple': 37,
#   'Lloyd’s Legendary Dragon': 2,
#   "Jay's Golden Dragon Motorbike": 19,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 61,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 76,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 89,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 102,
#   'Cole’s Dragon Cruiser': 3,
#   'Boba Fett’s Starship™': 38,
#   'Hoth™ AT-ST™': 23,
#   'Dark Trooper™ Attack': 24,
#   'Death Star™ Trench Run Diorama': 29,
#   'AT-ST™': 30,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 15,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 16,
#   'Batmobile™: The Penguin™ Chase': 27,
#   "Shuri's Lab": 46,
#   "Shuri's Lab_duplicate_1": 68,
#   "Shuri's Lab_duplicate_2": 81,
#   "Shuri's Lab_duplicate_3": 94,
#   "Shuri's Lab_duplicate_4": 107,
#   'King Namor’s Throne Room': 6,
#   'Batman™ versus Harley Quinn™': 49,
#   'Hogwarts™: Polyjuice Potion Mistake': 35,
#   'Hogwarts™ Magical Trunk': 34,
#   'Hogwarts™ Carriage and Thestrals': 14,
#   '007 Aston Martin DB5': 32,
#   'Fast & Furious 1970 Dodge Charger R/T': 33,
#   'T. rex Dinosaur Breakout': 17,
#   'T. rex & Atrociraptor Dinosaur Breakout': 4,
#   'Evil Macaque’s Mech': 10,
#   'Dragon of the East': 11},
#  'CareCreations': {'Flower Bouquet': 5,
#   'Wildflower Bouquet': 4,
#   'Creative Transparent Bricks': 49,
#   'Creative Transparent Bricks_duplicate_1': 71,
#   'Bricks and Functions': 50,
#   'Bricks and Functions_duplicate_1': 72,
#   'Creative Monkey Fun': 51,
#   'Creative Monkey Fun_duplicate_1': 73,
#   'Creative Monkey Fun_duplicate_2': 86,
#   'Creative Monkey Fun_duplicate_3': 99,
#   'Creative Monkey Fun_duplicate_4': 112,
#   'Statue of Liberty': 21,
#   'Singapore': 52,
#   'The "Abandoned" Mine': 53,
#   'The Ruined Portal': 54,
#   'The Nether Bastion': 22,
#   'Sonic the Hedgehog™ – Green Hill Zone': 11,
#   'Cyber Drone': 55,
#   'Cyber Drone_duplicate_1': 74,
#   'Cyber Drone_duplicate_2': 87,
#   'Cyber Drone_duplicate_3': 100,
#   'Cyber Drone_duplicate_4': 113,
#   'Surfer Beach House': 25,
#   'Off-road Buggy': 26,
#   'Off-road Buggy_duplicate_1': 65,
#   'Off-road Buggy_duplicate_2': 80,
#   'Off-road Buggy_duplicate_3': 93,
#   'Off-road Buggy_duplicate_4': 106,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 12,
#   'Super Robot_duplicate_1': 63,
#   'Super Robot_duplicate_2': 78,
#   'Super Robot_duplicate_3': 91,
#   'Super Robot_duplicate_4': 104,
#   'Street Racer': 24,
#   'Majestic Tiger': 28,
#   'Adorable Dogs': 27,
#   'Cozy House': 23,
#   'Sunflowers': 10,
#   'Sunflowers_duplicate_1': 62,
#   'Sunflowers_duplicate_2': 77,
#   'Sunflowers_duplicate_3': 90,
#   'Sunflowers_duplicate_4': 103,
#   'Forest Waterfall': 33,
#   'Pony-Washing Stable': 32,
#   'Pony-Washing Stable_duplicate_1': 66,
#   'Pony-Washing Stable_duplicate_2': 81,
#   'Pony-Washing Stable_duplicate_3': 94,
#   'Pony-Washing Stable_duplicate_4': 107,
#   'Pet Adoption Café': 31,
#   'Heartlake City Pizzeria': 41,
#   'Heartlake City Pizzeria_duplicate_1': 69,
#   'Heartlake City Pizzeria_duplicate_2': 84,
#   'Heartlake City Pizzeria_duplicate_3': 97,
#   'Heartlake City Pizzeria_duplicate_4': 110,
#   'Ice-Cream Truck': 40,
#   'Telehandler': 0,
#   'Telehandler_duplicate_1': 60,
#   'Telehandler_duplicate_2': 75,
#   'Telehandler_duplicate_3': 88,
#   'Telehandler_duplicate_4': 101,
#   'Material Handler': 8,
#   'Dump Truck': 9,
#   'Dump Truck_duplicate_1': 61,
#   'Dump Truck_duplicate_2': 76,
#   'Dump Truck_duplicate_3': 89,
#   'Dump Truck_duplicate_4': 102,
#   "Anna and Olaf's Castle Fun": 30,
#   'Jasmine and Mulan’s Adventure': 29,
#   'Space Ride Amusement Truck': 6,
#   'Police Mobile Command Truck': 39,
#   'Police Chase at the Bank': 38,
#   'Wild Animal Rescue Missions': 37,
#   'Cyber Stunt Bike': 34,
#   'Cyber Stunt Bike_duplicate_1': 67,
#   'Cyber Stunt Bike_duplicate_2': 82,
#   'Cyber Stunt Bike_duplicate_3': 95,
#   'Cyber Stunt Bike_duplicate_4': 108,
#   'ATV and Otter Habitat': 36,
#   'ATV and Otter Habitat_duplicate_1': 68,
#   'ATV and Otter Habitat_duplicate_2': 83,
#   'ATV and Otter Habitat_duplicate_3': 96,
#   'ATV and Otter Habitat_duplicate_4': 109,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 35,
#   'Lloyd’s Legendary Dragon': 19,
#   "Jay's Golden Dragon Motorbike": 18,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 64,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 79,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 92,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 105,
#   'Cole’s Dragon Cruiser': 17,
#   'Boba Fett’s Starship™': 3,
#   'Hoth™ AT-ST™': 15,
#   'Dark Trooper™ Attack': 16,
#   'Death Star™ Trench Run Diorama': 1,
#   'AT-ST™': 45,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 20,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 44,
#   'Batmobile™: The Penguin™ Chase': 47,
#   "Shuri's Lab": 48,
#   "Shuri's Lab_duplicate_1": 70,
#   "Shuri's Lab_duplicate_2": 85,
#   "Shuri's Lab_duplicate_3": 98,
#   "Shuri's Lab_duplicate_4": 111,
#   'King Namor’s Throne Room': 46,
#   'Batman™ versus Harley Quinn™': 56,
#   'Hogwarts™: Polyjuice Potion Mistake': 59,
#   'Hogwarts™ Magical Trunk': 57,
#   'Hogwarts™ Carriage and Thestrals': 58,
#   '007 Aston Martin DB5': 43,
#   'Fast & Furious 1970 Dodge Charger R/T': 42,
#   'T. rex Dinosaur Breakout': 14,
#   'T. rex & Atrociraptor Dinosaur Breakout': 13,
#   'Evil Macaque’s Mech': 7,
#   'Dragon of the East': 2},
#  'Calcifer': {'Flower Bouquet': 3,
#   'Wildflower Bouquet': 2,
#   'Creative Transparent Bricks': 29,
#   'Creative Transparent Bricks_duplicate_1': 66,
#   'Bricks and Functions': 30,
#   'Bricks and Functions_duplicate_1': 67,
#   'Creative Monkey Fun': 18,
#   'Creative Monkey Fun_duplicate_1': 63,
#   'Creative Monkey Fun_duplicate_2': 78,
#   'Creative Monkey Fun_duplicate_3': 91,
#   'Creative Monkey Fun_duplicate_4': 104,
#   'Statue of Liberty': 17,
#   'Singapore': 24,
#   'The "Abandoned" Mine': 28,
#   'The Ruined Portal': 16,
#   'The Nether Bastion': 27,
#   'Sonic the Hedgehog™ – Green Hill Zone': 0,
#   'Cyber Drone': 8,
#   'Cyber Drone_duplicate_1': 61,
#   'Cyber Drone_duplicate_2': 76,
#   'Cyber Drone_duplicate_3': 89,
#   'Cyber Drone_duplicate_4': 102,
#   'Surfer Beach House': 10,
#   'Off-road Buggy': 31,
#   'Off-road Buggy_duplicate_1': 68,
#   'Off-road Buggy_duplicate_2': 81,
#   'Off-road Buggy_duplicate_3': 94,
#   'Off-road Buggy_duplicate_4': 107,
#   'Off-road Buggy_duplicate_5': 115,
#   'Off-road Buggy_duplicate_6': 117,
#   'Off-road Buggy_duplicate_7': 119,
#   'Off-road Buggy_duplicate_8': 121,
#   'Off-road Buggy_duplicate_9': 123,
#   'Super Robot': 11,
#   'Super Robot_duplicate_1': 62,
#   'Super Robot_duplicate_2': 77,
#   'Super Robot_duplicate_3': 90,
#   'Super Robot_duplicate_4': 103,
#   'Street Racer': 9,
#   'Majestic Tiger': 15,
#   'Adorable Dogs': 32,
#   'Cozy House': 33,
#   'Sunflowers': 4,
#   'Sunflowers_duplicate_1': 60,
#   'Sunflowers_duplicate_2': 75,
#   'Sunflowers_duplicate_3': 88,
#   'Sunflowers_duplicate_4': 101,
#   'Forest Waterfall': 34,
#   'Pony-Washing Stable': 35,
#   'Pony-Washing Stable_duplicate_1': 69,
#   'Pony-Washing Stable_duplicate_2': 82,
#   'Pony-Washing Stable_duplicate_3': 95,
#   'Pony-Washing Stable_duplicate_4': 108,
#   'Pet Adoption Café': 36,
#   'Heartlake City Pizzeria': 37,
#   'Heartlake City Pizzeria_duplicate_1': 70,
#   'Heartlake City Pizzeria_duplicate_2': 83,
#   'Heartlake City Pizzeria_duplicate_3': 96,
#   'Heartlake City Pizzeria_duplicate_4': 109,
#   'Ice-Cream Truck': 38,
#   'Telehandler': 39,
#   'Telehandler_duplicate_1': 71,
#   'Telehandler_duplicate_2': 84,
#   'Telehandler_duplicate_3': 97,
#   'Telehandler_duplicate_4': 110,
#   'Material Handler': 1,
#   'Dump Truck': 23,
#   'Dump Truck_duplicate_1': 65,
#   'Dump Truck_duplicate_2': 80,
#   'Dump Truck_duplicate_3': 93,
#   'Dump Truck_duplicate_4': 106,
#   "Anna and Olaf's Castle Fun": 40,
#   'Jasmine and Mulan’s Adventure': 41,
#   'Space Ride Amusement Truck': 42,
#   'Police Mobile Command Truck': 43,
#   'Police Chase at the Bank': 14,
#   'Wild Animal Rescue Missions': 44,
#   'Cyber Stunt Bike': 45,
#   'Cyber Stunt Bike_duplicate_1': 72,
#   'Cyber Stunt Bike_duplicate_2': 85,
#   'Cyber Stunt Bike_duplicate_3': 98,
#   'Cyber Stunt Bike_duplicate_4': 111,
#   'ATV and Otter Habitat': 22,
#   'ATV and Otter Habitat_duplicate_1': 64,
#   'ATV and Otter Habitat_duplicate_2': 79,
#   'ATV and Otter Habitat_duplicate_3': 92,
#   'ATV and Otter Habitat_duplicate_4': 105,
#   'ATV and Otter Habitat_duplicate_5': 114,
#   'ATV and Otter Habitat_duplicate_6': 116,
#   'ATV and Otter Habitat_duplicate_7': 118,
#   'ATV and Otter Habitat_duplicate_8': 120,
#   'ATV and Otter Habitat_duplicate_9': 122,
#   'Ninja Dragon Temple': 46,
#   'Lloyd’s Legendary Dragon': 6,
#   "Jay's Golden Dragon Motorbike": 47,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 73,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 86,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 99,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 112,
#   'Cole’s Dragon Cruiser': 25,
#   'Boba Fett’s Starship™': 7,
#   'Hoth™ AT-ST™': 19,
#   'Dark Trooper™ Attack': 48,
#   'Death Star™ Trench Run Diorama': 5,
#   'AT-ST™': 49,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 20,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 50,
#   'Batmobile™: The Penguin™ Chase': 21,
#   "Shuri's Lab": 51,
#   "Shuri's Lab_duplicate_1": 74,
#   "Shuri's Lab_duplicate_2": 87,
#   "Shuri's Lab_duplicate_3": 100,
#   "Shuri's Lab_duplicate_4": 113,
#   'King Namor’s Throne Room': 26,
#   'Batman™ versus Harley Quinn™': 52,
#   'Hogwarts™: Polyjuice Potion Mistake': 53,
#   'Hogwarts™ Magical Trunk': 54,
#   'Hogwarts™ Carriage and Thestrals': 55,
#   '007 Aston Martin DB5': 12,
#   'Fast & Furious 1970 Dodge Charger R/T': 13,
#   'T. rex Dinosaur Breakout': 56,
#   'T. rex & Atrociraptor Dinosaur Breakout': 57,
#   'Evil Macaque’s Mech': 58,
#   'Dragon of the East': 59},
#  'Kraata Kink': {'Flower Bouquet': 7,
#   'Wildflower Bouquet': 8,
#   'Creative Transparent Bricks': 16,
#   'Creative Transparent Bricks_duplicate_1': 62,
#   'Bricks and Functions': 15,
#   'Bricks and Functions_duplicate_1': 61,
#   'Creative Monkey Fun': 14,
#   'Creative Monkey Fun_duplicate_1': 60,
#   'Creative Monkey Fun_duplicate_2': 75,
#   'Creative Monkey Fun_duplicate_3': 88,
#   'Creative Monkey Fun_duplicate_4': 101,
#   'Statue of Liberty': 3,
#   'Singapore': 9,
#   'The "Abandoned" Mine': 10,
#   'The Ruined Portal': 11,
#   'The Nether Bastion': 13,
#   'Sonic the Hedgehog™ – Green Hill Zone': 12,
#   'Cyber Drone': 17,
#   'Cyber Drone_duplicate_1': 63,
#   'Cyber Drone_duplicate_2': 76,
#   'Cyber Drone_duplicate_3': 89,
#   'Cyber Drone_duplicate_4': 102,
#   'Surfer Beach House': 18,
#   'Off-road Buggy': 19,
#   'Off-road Buggy_duplicate_1': 64,
#   'Off-road Buggy_duplicate_2': 77,
#   'Off-road Buggy_duplicate_3': 90,
#   'Off-road Buggy_duplicate_4': 103,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 20,
#   'Super Robot_duplicate_1': 65,
#   'Super Robot_duplicate_2': 78,
#   'Super Robot_duplicate_3': 91,
#   'Super Robot_duplicate_4': 104,
#   'Street Racer': 21,
#   'Majestic Tiger': 6,
#   'Adorable Dogs': 22,
#   'Cozy House': 23,
#   'Sunflowers': 24,
#   'Sunflowers_duplicate_1': 66,
#   'Sunflowers_duplicate_2': 79,
#   'Sunflowers_duplicate_3': 92,
#   'Sunflowers_duplicate_4': 105,
#   'Forest Waterfall': 25,
#   'Pony-Washing Stable': 26,
#   'Pony-Washing Stable_duplicate_1': 67,
#   'Pony-Washing Stable_duplicate_2': 80,
#   'Pony-Washing Stable_duplicate_3': 93,
#   'Pony-Washing Stable_duplicate_4': 106,
#   'Pet Adoption Café': 27,
#   'Heartlake City Pizzeria': 28,
#   'Heartlake City Pizzeria_duplicate_1': 68,
#   'Heartlake City Pizzeria_duplicate_2': 81,
#   'Heartlake City Pizzeria_duplicate_3': 94,
#   'Heartlake City Pizzeria_duplicate_4': 107,
#   'Ice-Cream Truck': 29,
#   'Telehandler': 30,
#   'Telehandler_duplicate_1': 69,
#   'Telehandler_duplicate_2': 82,
#   'Telehandler_duplicate_3': 95,
#   'Telehandler_duplicate_4': 108,
#   'Material Handler': 2,
#   'Dump Truck': 31,
#   'Dump Truck_duplicate_1': 70,
#   'Dump Truck_duplicate_2': 83,
#   'Dump Truck_duplicate_3': 96,
#   'Dump Truck_duplicate_4': 109,
#   "Anna and Olaf's Castle Fun": 32,
#   'Jasmine and Mulan’s Adventure': 33,
#   'Space Ride Amusement Truck': 34,
#   'Police Mobile Command Truck': 35,
#   'Police Chase at the Bank': 36,
#   'Wild Animal Rescue Missions': 37,
#   'Cyber Stunt Bike': 38,
#   'Cyber Stunt Bike_duplicate_1': 71,
#   'Cyber Stunt Bike_duplicate_2': 84,
#   'Cyber Stunt Bike_duplicate_3': 97,
#   'Cyber Stunt Bike_duplicate_4': 110,
#   'ATV and Otter Habitat': 39,
#   'ATV and Otter Habitat_duplicate_1': 72,
#   'ATV and Otter Habitat_duplicate_2': 85,
#   'ATV and Otter Habitat_duplicate_3': 98,
#   'ATV and Otter Habitat_duplicate_4': 111,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 40,
#   'Lloyd’s Legendary Dragon': 41,
#   "Jay's Golden Dragon Motorbike": 42,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 73,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 86,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 99,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 112,
#   'Cole’s Dragon Cruiser': 43,
#   'Boba Fett’s Starship™': 44,
#   'Hoth™ AT-ST™': 55,
#   'Dark Trooper™ Attack': 46,
#   'Death Star™ Trench Run Diorama': 47,
#   'AT-ST™': 48,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 49,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 50,
#   'Batmobile™: The Penguin™ Chase': 51,
#   "Shuri's Lab": 52,
#   "Shuri's Lab_duplicate_1": 74,
#   "Shuri's Lab_duplicate_2": 87,
#   "Shuri's Lab_duplicate_3": 100,
#   "Shuri's Lab_duplicate_4": 113,
#   'King Namor’s Throne Room': 53,
#   'Batman™ versus Harley Quinn™': 54,
#   'Hogwarts™: Polyjuice Potion Mistake': 56,
#   'Hogwarts™ Magical Trunk': 59,
#   'Hogwarts™ Carriage and Thestrals': 45,
#   '007 Aston Martin DB5': 57,
#   'Fast & Furious 1970 Dodge Charger R/T': 58,
#   'T. rex Dinosaur Breakout': 4,
#   'T. rex & Atrociraptor Dinosaur Breakout': 1,
#   'Evil Macaque’s Mech': 0,
#   'Dragon of the East': 5},
#  'Kanakalackin': {'Flower Bouquet': 0,
#   'Wildflower Bouquet': 1,
#   'Creative Transparent Bricks': 22,
#   'Creative Transparent Bricks_duplicate_1': 67,
#   'Bricks and Functions': 23,
#   'Bricks and Functions_duplicate_1': 68,
#   'Creative Monkey Fun': 4,
#   'Creative Monkey Fun_duplicate_1': 61,
#   'Creative Monkey Fun_duplicate_2': 76,
#   'Creative Monkey Fun_duplicate_3': 89,
#   'Creative Monkey Fun_duplicate_4': 102,
#   'Statue of Liberty': 25,
#   'Singapore': 24,
#   'The "Abandoned" Mine': 26,
#   'The Ruined Portal': 27,
#   'The Nether Bastion': 28,
#   'Sonic the Hedgehog™ – Green Hill Zone': 8,
#   'Cyber Drone': 3,
#   'Cyber Drone_duplicate_1': 60,
#   'Cyber Drone_duplicate_2': 75,
#   'Cyber Drone_duplicate_3': 88,
#   'Cyber Drone_duplicate_4': 101,
#   'Surfer Beach House': 10,
#   'Off-road Buggy': 9,
#   'Off-road Buggy_duplicate_1': 64,
#   'Off-road Buggy_duplicate_2': 79,
#   'Off-road Buggy_duplicate_3': 92,
#   'Off-road Buggy_duplicate_4': 105,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 5,
#   'Super Robot_duplicate_1': 62,
#   'Super Robot_duplicate_2': 77,
#   'Super Robot_duplicate_3': 90,
#   'Super Robot_duplicate_4': 103,
#   'Street Racer': 11,
#   'Majestic Tiger': 6,
#   'Adorable Dogs': 12,
#   'Cozy House': 29,
#   'Sunflowers': 7,
#   'Sunflowers_duplicate_1': 63,
#   'Sunflowers_duplicate_2': 78,
#   'Sunflowers_duplicate_3': 91,
#   'Sunflowers_duplicate_4': 104,
#   'Forest Waterfall': 37,
#   'Pony-Washing Stable': 38,
#   'Pony-Washing Stable_duplicate_1': 70,
#   'Pony-Washing Stable_duplicate_2': 83,
#   'Pony-Washing Stable_duplicate_3': 96,
#   'Pony-Washing Stable_duplicate_4': 109,
#   'Pet Adoption Café': 39,
#   'Heartlake City Pizzeria': 40,
#   'Heartlake City Pizzeria_duplicate_1': 71,
#   'Heartlake City Pizzeria_duplicate_2': 84,
#   'Heartlake City Pizzeria_duplicate_3': 97,
#   'Heartlake City Pizzeria_duplicate_4': 110,
#   'Ice-Cream Truck': 41,
#   'Telehandler': 42,
#   'Telehandler_duplicate_1': 72,
#   'Telehandler_duplicate_2': 85,
#   'Telehandler_duplicate_3': 98,
#   'Telehandler_duplicate_4': 111,
#   'Material Handler': 14,
#   'Dump Truck': 13,
#   'Dump Truck_duplicate_1': 65,
#   'Dump Truck_duplicate_2': 80,
#   'Dump Truck_duplicate_3': 93,
#   'Dump Truck_duplicate_4': 106,
#   "Anna and Olaf's Castle Fun": 43,
#   'Jasmine and Mulan’s Adventure': 44,
#   'Space Ride Amusement Truck': 45,
#   'Police Mobile Command Truck': 46,
#   'Police Chase at the Bank': 47,
#   'Wild Animal Rescue Missions': 16,
#   'Cyber Stunt Bike': 48,
#   'Cyber Stunt Bike_duplicate_1': 73,
#   'Cyber Stunt Bike_duplicate_2': 86,
#   'Cyber Stunt Bike_duplicate_3': 99,
#   'Cyber Stunt Bike_duplicate_4': 112,
#   'ATV and Otter Habitat': 15,
#   'ATV and Otter Habitat_duplicate_1': 66,
#   'ATV and Otter Habitat_duplicate_2': 81,
#   'ATV and Otter Habitat_duplicate_3': 94,
#   'ATV and Otter Habitat_duplicate_4': 107,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 2,
#   'Lloyd’s Legendary Dragon': 30,
#   "Jay's Golden Dragon Motorbike": 31,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 69,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 82,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 95,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 108,
#   'Cole’s Dragon Cruiser': 32,
#   'Boba Fett’s Starship™': 17,
#   'Hoth™ AT-ST™': 18,
#   'Dark Trooper™ Attack': 49,
#   'Death Star™ Trench Run Diorama': 19,
#   'AT-ST™': 50,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 51,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 55,
#   'Batmobile™: The Penguin™ Chase': 53,
#   "Shuri's Lab": 52,
#   "Shuri's Lab_duplicate_1": 74,
#   "Shuri's Lab_duplicate_2": 87,
#   "Shuri's Lab_duplicate_3": 100,
#   "Shuri's Lab_duplicate_4": 113,
#   'King Namor’s Throne Room': 54,
#   'Batman™ versus Harley Quinn™': 56,
#   'Hogwarts™: Polyjuice Potion Mistake': 58,
#   'Hogwarts™ Magical Trunk': 57,
#   'Hogwarts™ Carriage and Thestrals': 59,
#   '007 Aston Martin DB5': 21,
#   'Fast & Furious 1970 Dodge Charger R/T': 20,
#   'T. rex Dinosaur Breakout': 35,
#   'T. rex & Atrociraptor Dinosaur Breakout': 36,
#   'Evil Macaque’s Mech': 34,
#   'Dragon of the East': 33},
#  'Steve the Squid': {'Flower Bouquet': 10,
#   'Wildflower Bouquet': 1,
#   'Creative Transparent Bricks': 44,
#   'Creative Transparent Bricks_duplicate_1': 62,
#   'Bricks and Functions': 43,
#   'Bricks and Functions_duplicate_1': 61,
#   'Creative Monkey Fun': 50,
#   'Creative Monkey Fun_duplicate_1': 66,
#   'Creative Monkey Fun_duplicate_2': 79,
#   'Creative Monkey Fun_duplicate_3': 92,
#   'Creative Monkey Fun_duplicate_4': 105,
#   'Statue of Liberty': 17,
#   'Singapore': 20,
#   'The "Abandoned" Mine': 27,
#   'The Ruined Portal': 26,
#   'The Nether Bastion': 23,
#   'Sonic the Hedgehog™ – Green Hill Zone': 3,
#   'Cyber Drone': 53,
#   'Cyber Drone_duplicate_1': 69,
#   'Cyber Drone_duplicate_2': 82,
#   'Cyber Drone_duplicate_3': 95,
#   'Cyber Drone_duplicate_4': 108,
#   'Surfer Beach House': 19,
#   'Off-road Buggy': 57,
#   'Off-road Buggy_duplicate_1': 72,
#   'Off-road Buggy_duplicate_2': 85,
#   'Off-road Buggy_duplicate_3': 98,
#   'Off-road Buggy_duplicate_4': 111,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 52,
#   'Super Robot_duplicate_1': 68,
#   'Super Robot_duplicate_2': 81,
#   'Super Robot_duplicate_3': 94,
#   'Super Robot_duplicate_4': 107,
#   'Street Racer': 22,
#   'Majestic Tiger': 8,
#   'Adorable Dogs': 16,
#   'Cozy House': 18,
#   'Sunflowers': 51,
#   'Sunflowers_duplicate_1': 67,
#   'Sunflowers_duplicate_2': 80,
#   'Sunflowers_duplicate_3': 93,
#   'Sunflowers_duplicate_4': 106,
#   'Forest Waterfall': 38,
#   'Pony-Washing Stable': 56,
#   'Pony-Washing Stable_duplicate_1': 71,
#   'Pony-Washing Stable_duplicate_2': 84,
#   'Pony-Washing Stable_duplicate_3': 97,
#   'Pony-Washing Stable_duplicate_4': 110,
#   'Pet Adoption Café': 39,
#   'Heartlake City Pizzeria': 49,
#   'Heartlake City Pizzeria_duplicate_1': 65,
#   'Heartlake City Pizzeria_duplicate_2': 78,
#   'Heartlake City Pizzeria_duplicate_3': 91,
#   'Heartlake City Pizzeria_duplicate_4': 104,
#   'Ice-Cream Truck': 40,
#   'Telehandler': 47,
#   'Telehandler_duplicate_1': 63,
#   'Telehandler_duplicate_2': 76,
#   'Telehandler_duplicate_3': 89,
#   'Telehandler_duplicate_4': 102,
#   'Material Handler': 2,
#   'Dump Truck': 48,
#   'Dump Truck_duplicate_1': 64,
#   'Dump Truck_duplicate_2': 77,
#   'Dump Truck_duplicate_3': 90,
#   'Dump Truck_duplicate_4': 103,
#   "Anna and Olaf's Castle Fun": 36,
#   'Jasmine and Mulan’s Adventure': 37,
#   'Space Ride Amusement Truck': 4,
#   'Police Mobile Command Truck': 25,
#   'Police Chase at the Bank': 24,
#   'Wild Animal Rescue Missions': 31,
#   'Cyber Stunt Bike': 59,
#   'Cyber Stunt Bike_duplicate_1': 74,
#   'Cyber Stunt Bike_duplicate_2': 87,
#   'Cyber Stunt Bike_duplicate_3': 100,
#   'Cyber Stunt Bike_duplicate_4': 113,
#   'ATV and Otter Habitat': 58,
#   'ATV and Otter Habitat_duplicate_1': 73,
#   'ATV and Otter Habitat_duplicate_2': 86,
#   'ATV and Otter Habitat_duplicate_3': 99,
#   'ATV and Otter Habitat_duplicate_4': 112,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 54,
#   'Lloyd’s Legendary Dragon': 5,
#   "Jay's Golden Dragon Motorbike": 42,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 60,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 75,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 88,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 101,
#   'Cole’s Dragon Cruiser': 14,
#   'Boba Fett’s Starship™': 13,
#   'Hoth™ AT-ST™': 9,
#   'Dark Trooper™ Attack': 30,
#   'Death Star™ Trench Run Diorama': 11,
#   'AT-ST™': 41,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 12,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 33,
#   'Batmobile™: The Penguin™ Chase': 29,
#   "Shuri's Lab": 55,
#   "Shuri's Lab_duplicate_1": 70,
#   "Shuri's Lab_duplicate_2": 83,
#   "Shuri's Lab_duplicate_3": 96,
#   "Shuri's Lab_duplicate_4": 109,
#   'King Namor’s Throne Room': 21,
#   'Batman™ versus Harley Quinn™': 46,
#   'Hogwarts™: Polyjuice Potion Mistake': 45,
#   'Hogwarts™ Magical Trunk': 28,
#   'Hogwarts™ Carriage and Thestrals': 32,
#   '007 Aston Martin DB5': 35,
#   'Fast & Furious 1970 Dodge Charger R/T': 34,
#   'T. rex Dinosaur Breakout': 6,
#   'T. rex & Atrociraptor Dinosaur Breakout': 7,
#   'Evil Macaque’s Mech': 15,
#   'Dragon of the East': 0},
#  'ChocolateFrogs': {'Flower Bouquet': 50,
#   'Wildflower Bouquet': 11,
#   'Creative Transparent Bricks': 10,
#   'Creative Transparent Bricks_duplicate_1': 60,
#   'Bricks and Functions': 29,
#   'Bricks and Functions_duplicate_1': 64,
#   'Creative Monkey Fun': 59,
#   'Creative Monkey Fun_duplicate_1': 74,
#   'Creative Monkey Fun_duplicate_2': 87,
#   'Creative Monkey Fun_duplicate_3': 100,
#   'Creative Monkey Fun_duplicate_4': 113,
#   'Statue of Liberty': 4,
#   'Singapore': 20,
#   'The "Abandoned" Mine': 26,
#   'The Ruined Portal': 12,
#   'The Nether Bastion': 51,
#   'Sonic the Hedgehog™ – Green Hill Zone': 56,
#   'Cyber Drone': 47,
#   'Cyber Drone_duplicate_1': 71,
#   'Cyber Drone_duplicate_2': 84,
#   'Cyber Drone_duplicate_3': 97,
#   'Cyber Drone_duplicate_4': 110,
#   'Surfer Beach House': 5,
#   'Off-road Buggy': 34,
#   'Off-road Buggy_duplicate_1': 65,
#   'Off-road Buggy_duplicate_2': 78,
#   'Off-road Buggy_duplicate_3': 91,
#   'Off-road Buggy_duplicate_4': 104,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 44,
#   'Super Robot_duplicate_1': 69,
#   'Super Robot_duplicate_2': 82,
#   'Super Robot_duplicate_3': 95,
#   'Super Robot_duplicate_4': 108,
#   'Street Racer': 23,
#   'Majestic Tiger': 7,
#   'Adorable Dogs': 22,
#   'Cozy House': 0,
#   'Sunflowers': 24,
#   'Sunflowers_duplicate_1': 63,
#   'Sunflowers_duplicate_2': 77,
#   'Sunflowers_duplicate_3': 90,
#   'Sunflowers_duplicate_4': 103,
#   'Forest Waterfall': 54,
#   'Pony-Washing Stable': 55,
#   'Pony-Washing Stable_duplicate_1': 73,
#   'Pony-Washing Stable_duplicate_2': 86,
#   'Pony-Washing Stable_duplicate_3': 99,
#   'Pony-Washing Stable_duplicate_4': 112,
#   'Pet Adoption Café': 21,
#   'Heartlake City Pizzeria': 46,
#   'Heartlake City Pizzeria_duplicate_1': 70,
#   'Heartlake City Pizzeria_duplicate_2': 83,
#   'Heartlake City Pizzeria_duplicate_3': 96,
#   'Heartlake City Pizzeria_duplicate_4': 109,
#   'Ice-Cream Truck': 40,
#   'Telehandler': 43,
#   'Telehandler_duplicate_1': 68,
#   'Telehandler_duplicate_2': 81,
#   'Telehandler_duplicate_3': 94,
#   'Telehandler_duplicate_4': 107,
#   'Material Handler': 15,
#   'Dump Truck': 18,
#   'Dump Truck_duplicate_1': 62,
#   'Dump Truck_duplicate_2': 76,
#   'Dump Truck_duplicate_3': 89,
#   'Dump Truck_duplicate_4': 102,
#   "Anna and Olaf's Castle Fun": 58,
#   'Jasmine and Mulan’s Adventure': 37,
#   'Space Ride Amusement Truck': 9,
#   'Police Mobile Command Truck': 27,
#   'Police Chase at the Bank': 25,
#   'Wild Animal Rescue Missions': 13,
#   'Cyber Stunt Bike': 36,
#   'Cyber Stunt Bike_duplicate_1': 67,
#   'Cyber Stunt Bike_duplicate_2': 80,
#   'Cyber Stunt Bike_duplicate_3': 93,
#   'Cyber Stunt Bike_duplicate_4': 106,
#   'ATV and Otter Habitat': 35,
#   'ATV and Otter Habitat_duplicate_1': 66,
#   'ATV and Otter Habitat_duplicate_2': 79,
#   'ATV and Otter Habitat_duplicate_3': 92,
#   'ATV and Otter Habitat_duplicate_4': 105,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 41,
#   'Lloyd’s Legendary Dragon': 16,
#   "Jay's Golden Dragon Motorbike": 14,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 61,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 75,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 88,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 101,
#   'Cole’s Dragon Cruiser': 17,
#   'Boba Fett’s Starship™': 8,
#   'Hoth™ AT-ST™': 33,
#   'Dark Trooper™ Attack': 32,
#   'Death Star™ Trench Run Diorama': 1,
#   'AT-ST™': 52,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 42,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 31,
#   'Batmobile™: The Penguin™ Chase': 30,
#   "Shuri's Lab": 53,
#   "Shuri's Lab_duplicate_1": 72,
#   "Shuri's Lab_duplicate_2": 85,
#   "Shuri's Lab_duplicate_3": 98,
#   "Shuri's Lab_duplicate_4": 111,
#   'King Namor’s Throne Room': 49,
#   'Batman™ versus Harley Quinn™': 57,
#   'Hogwarts™: Polyjuice Potion Mistake': 48,
#   'Hogwarts™ Magical Trunk': 6,
#   'Hogwarts™ Carriage and Thestrals': 28,
#   '007 Aston Martin DB5': 45,
#   'Fast & Furious 1970 Dodge Charger R/T': 19,
#   'T. rex Dinosaur Breakout': 38,
#   'T. rex & Atrociraptor Dinosaur Breakout': 39,
#   'Evil Macaque’s Mech': 2,
#   'Dragon of the East': 3},
#  'Ta-metru_defender': {'Flower Bouquet': 18,
#   'Wildflower Bouquet': 0,
#   'Creative Transparent Bricks': 27,
#   'Creative Transparent Bricks_duplicate_1': 64,
#   'Bricks and Functions': 45,
#   'Bricks and Functions_duplicate_1': 73,
#   'Creative Monkey Fun': 40,
#   'Creative Monkey Fun_duplicate_1': 70,
#   'Creative Monkey Fun_duplicate_2': 84,
#   'Creative Monkey Fun_duplicate_3': 97,
#   'Creative Monkey Fun_duplicate_4': 110,
#   'Statue of Liberty': 16,
#   'Singapore': 15,
#   'The "Abandoned" Mine': 59,
#   'The Ruined Portal': 58,
#   'The Nether Bastion': 57,
#   'Sonic the Hedgehog™ – Green Hill Zone': 39,
#   'Cyber Drone': 29,
#   'Cyber Drone_duplicate_1': 66,
#   'Cyber Drone_duplicate_2': 80,
#   'Cyber Drone_duplicate_3': 93,
#   'Cyber Drone_duplicate_4': 106,
#   'Surfer Beach House': 32,
#   'Off-road Buggy': 28,
#   'Off-road Buggy_duplicate_1': 65,
#   'Off-road Buggy_duplicate_2': 79,
#   'Off-road Buggy_duplicate_3': 92,
#   'Off-road Buggy_duplicate_4': 105,
#   'Off-road Buggy_duplicate_5': 115,
#   'Off-road Buggy_duplicate_6': 117,
#   'Off-road Buggy_duplicate_7': 119,
#   'Off-road Buggy_duplicate_8': 121,
#   'Off-road Buggy_duplicate_9': 123,
#   'Super Robot': 17,
#   'Super Robot_duplicate_1': 61,
#   'Super Robot_duplicate_2': 76,
#   'Super Robot_duplicate_3': 89,
#   'Super Robot_duplicate_4': 102,
#   'Street Racer': 46,
#   'Majestic Tiger': 14,
#   'Adorable Dogs': 33,
#   'Cozy House': 5,
#   'Sunflowers': 19,
#   'Sunflowers_duplicate_1': 62,
#   'Sunflowers_duplicate_2': 77,
#   'Sunflowers_duplicate_3': 90,
#   'Sunflowers_duplicate_4': 103,
#   'Forest Waterfall': 30,
#   'Pony-Washing Stable': 52,
#   'Pony-Washing Stable_duplicate_1': 74,
#   'Pony-Washing Stable_duplicate_2': 87,
#   'Pony-Washing Stable_duplicate_3': 100,
#   'Pony-Washing Stable_duplicate_4': 113,
#   'Pet Adoption Café': 51,
#   'Heartlake City Pizzeria': 23,
#   'Heartlake City Pizzeria_duplicate_1': 63,
#   'Heartlake City Pizzeria_duplicate_2': 78,
#   'Heartlake City Pizzeria_duplicate_3': 91,
#   'Heartlake City Pizzeria_duplicate_4': 104,
#   'Ice-Cream Truck': 56,
#   'Telehandler': 41,
#   'Telehandler_duplicate_1': 71,
#   'Telehandler_duplicate_2': 85,
#   'Telehandler_duplicate_3': 98,
#   'Telehandler_duplicate_4': 111,
#   'Material Handler': 48,
#   'Dump Truck': 38,
#   'Dump Truck_duplicate_1': 69,
#   'Dump Truck_duplicate_2': 83,
#   'Dump Truck_duplicate_3': 96,
#   'Dump Truck_duplicate_4': 109,
#   "Anna and Olaf's Castle Fun": 54,
#   'Jasmine and Mulan’s Adventure': 21,
#   'Space Ride Amusement Truck': 26,
#   'Police Mobile Command Truck': 47,
#   'Police Chase at the Bank': 8,
#   'Wild Animal Rescue Missions': 53,
#   'Cyber Stunt Bike': 44,
#   'Cyber Stunt Bike_duplicate_1': 72,
#   'Cyber Stunt Bike_duplicate_2': 86,
#   'Cyber Stunt Bike_duplicate_3': 99,
#   'Cyber Stunt Bike_duplicate_4': 112,
#   'ATV and Otter Habitat': 4,
#   'ATV and Otter Habitat_duplicate_1': 60,
#   'ATV and Otter Habitat_duplicate_2': 75,
#   'ATV and Otter Habitat_duplicate_3': 88,
#   'ATV and Otter Habitat_duplicate_4': 101,
#   'ATV and Otter Habitat_duplicate_5': 114,
#   'ATV and Otter Habitat_duplicate_6': 116,
#   'ATV and Otter Habitat_duplicate_7': 118,
#   'ATV and Otter Habitat_duplicate_8': 120,
#   'ATV and Otter Habitat_duplicate_9': 122,
#   'Ninja Dragon Temple': 55,
#   'Lloyd’s Legendary Dragon': 11,
#   "Jay's Golden Dragon Motorbike": 37,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 68,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 82,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 95,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 108,
#   'Cole’s Dragon Cruiser': 31,
#   'Boba Fett’s Starship™': 7,
#   'Hoth™ AT-ST™': 1,
#   'Dark Trooper™ Attack': 24,
#   'Death Star™ Trench Run Diorama': 12,
#   'AT-ST™': 20,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 22,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 2,
#   'Batmobile™: The Penguin™ Chase': 9,
#   "Shuri's Lab": 34,
#   "Shuri's Lab_duplicate_1": 67,
#   "Shuri's Lab_duplicate_2": 81,
#   "Shuri's Lab_duplicate_3": 94,
#   "Shuri's Lab_duplicate_4": 107,
#   'King Namor’s Throne Room': 43,
#   'Batman™ versus Harley Quinn™': 35,
#   'Hogwarts™: Polyjuice Potion Mistake': 25,
#   'Hogwarts™ Magical Trunk': 3,
#   'Hogwarts™ Carriage and Thestrals': 36,
#   '007 Aston Martin DB5': 50,
#   'Fast & Furious 1970 Dodge Charger R/T': 49,
#   'T. rex Dinosaur Breakout': 42,
#   'T. rex & Atrociraptor Dinosaur Breakout': 13,
#   'Evil Macaque’s Mech': 6,
#   'Dragon of the East': 10},
#  'TuragaNuva': {'Flower Bouquet': 2,
#   'Wildflower Bouquet': 3,
#   'Creative Transparent Bricks': 24,
#   'Creative Transparent Bricks_duplicate_1': 69,
#   'Bricks and Functions': 25,
#   'Bricks and Functions_duplicate_1': 70,
#   'Creative Monkey Fun': 55,
#   'Creative Monkey Fun_duplicate_1': 74,
#   'Creative Monkey Fun_duplicate_2': 87,
#   'Creative Monkey Fun_duplicate_3': 100,
#   'Creative Monkey Fun_duplicate_4': 113,
#   'Statue of Liberty': 39,
#   'Singapore': 41,
# ...
#   'Street Racer': 13,
#   'Majestic Tiger': 11,
#   'Adorable Dogs': 40,
#   'Cozy House': 41,
#   'Sunflowers': 42,
#   'Sunflowers_duplicate_1': 69,
#   'Sunflowers_duplicate_2': 82,
#   'Sunflowers_duplicate_3': 95,
#   'Sunflowers_duplicate_4': 108,
#   'Forest Waterfall': 43,
#   'Pony-Washing Stable': 44,
#   'Pony-Washing Stable_duplicate_1': 70,
#   'Pony-Washing Stable_duplicate_2': 83,
#   'Pony-Washing Stable_duplicate_3': 96,
#   'Pony-Washing Stable_duplicate_4': 109,
#   'Pet Adoption Café': 45,
#   'Heartlake City Pizzeria': 46,
#   'Heartlake City Pizzeria_duplicate_1': 71,
#   'Heartlake City Pizzeria_duplicate_2': 84,
#   'Heartlake City Pizzeria_duplicate_3': 97,
#   'Heartlake City Pizzeria_duplicate_4': 110,
#   'Ice-Cream Truck': 47,
#   'Telehandler': 48,
#   'Telehandler_duplicate_1': 72,
#   'Telehandler_duplicate_2': 85,
#   'Telehandler_duplicate_3': 98,
#   'Telehandler_duplicate_4': 111,
#   'Material Handler': 0,
#   'Dump Truck': 49,
#   'Dump Truck_duplicate_1': 73,
#   'Dump Truck_duplicate_2': 86,
#   'Dump Truck_duplicate_3': 99,
#   'Dump Truck_duplicate_4': 112,
#   "Anna and Olaf's Castle Fun": 50,
#   'Jasmine and Mulan’s Adventure': 51,
#   'Space Ride Amusement Truck': 16,
#   'Police Mobile Command Truck': 15,
#   'Police Chase at the Bank': 14,
#   'Wild Animal Rescue Missions': 17,
#   'Cyber Stunt Bike': 18,
#   'Cyber Stunt Bike_duplicate_1': 61,
#   'Cyber Stunt Bike_duplicate_2': 76,
#   'Cyber Stunt Bike_duplicate_3': 89,
#   'Cyber Stunt Bike_duplicate_4': 102,
#   'ATV and Otter Habitat': 29,
#   'ATV and Otter Habitat_duplicate_1': 63,
#   'ATV and Otter Habitat_duplicate_2': 78,
#   'ATV and Otter Habitat_duplicate_3': 91,
#   'ATV and Otter Habitat_duplicate_4': 104,
#   'ATV and Otter Habitat_duplicate_5': 114,
#   'ATV and Otter Habitat_duplicate_6': 116,
#   'ATV and Otter Habitat_duplicate_7': 118,
#   'ATV and Otter Habitat_duplicate_8': 120,
#   'ATV and Otter Habitat_duplicate_9': 122,
#   'Ninja Dragon Temple': 28,
#   'Lloyd’s Legendary Dragon': 1,
#   "Jay's Golden Dragon Motorbike": 19,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 62,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 77,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 90,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 103,
#   'Cole’s Dragon Cruiser': 6,
#   'Boba Fett’s Starship™': 20,
#   'Hoth™ AT-ST™': 7,
#   'Dark Trooper™ Attack': 21,
#   'Death Star™ Trench Run Diorama': 5,
#   'AT-ST™': 27,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 22,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 23,
#   'Batmobile™: The Penguin™ Chase': 24,
#   "Shuri's Lab": 52,
#   "Shuri's Lab_duplicate_1": 74,
#   "Shuri's Lab_duplicate_2": 87,
#   "Shuri's Lab_duplicate_3": 100,
#   "Shuri's Lab_duplicate_4": 113,
#   'King Namor’s Throne Room': 53,
#   'Batman™ versus Harley Quinn™': 54,
#   'Hogwarts™: Polyjuice Potion Mistake': 55,
#   'Hogwarts™ Magical Trunk': 56,
#   'Hogwarts™ Carriage and Thestrals': 57,
#   '007 Aston Martin DB5': 25,
#   'Fast & Furious 1970 Dodge Charger R/T': 26,
#   'T. rex Dinosaur Breakout': 58,
#   'T. rex & Atrociraptor Dinosaur Breakout': 59,
#   'Evil Macaque’s Mech': 3,
#   'Dragon of the East': 4},
#  'alex_mocs': {'Flower Bouquet': 0,
#   'Wildflower Bouquet': 1,
#   'Creative Transparent Bricks': 24,
#   'Creative Transparent Bricks_duplicate_1': 64,
#   'Bricks and Functions': 31,
#   'Bricks and Functions_duplicate_1': 67,
#   'Creative Monkey Fun': 21,
#   'Creative Monkey Fun_duplicate_1': 63,
#   'Creative Monkey Fun_duplicate_2': 78,
#   'Creative Monkey Fun_duplicate_3': 91,
#   'Creative Monkey Fun_duplicate_4': 104,
#   'Statue of Liberty': 9,
#   'Singapore': 22,
#   'The "Abandoned" Mine': 39,
#   'The Ruined Portal': 40,
#   'The Nether Bastion': 41,
#   'Sonic the Hedgehog™ – Green Hill Zone': 32,
#   'Cyber Drone': 33,
#   'Cyber Drone_duplicate_1': 68,
#   'Cyber Drone_duplicate_2': 81,
#   'Cyber Drone_duplicate_3': 94,
#   'Cyber Drone_duplicate_4': 107,
#   'Surfer Beach House': 26,
#   'Off-road Buggy': 29,
#   'Off-road Buggy_duplicate_1': 66,
#   'Off-road Buggy_duplicate_2': 80,
#   'Off-road Buggy_duplicate_3': 93,
#   'Off-road Buggy_duplicate_4': 106,
#   'Off-road Buggy_duplicate_5': 114,
#   'Off-road Buggy_duplicate_6': 116,
#   'Off-road Buggy_duplicate_7': 118,
#   'Off-road Buggy_duplicate_8': 120,
#   'Off-road Buggy_duplicate_9': 122,
#   'Super Robot': 14,
#   'Super Robot_duplicate_1': 61,
#   'Super Robot_duplicate_2': 76,
#   'Super Robot_duplicate_3': 89,
#   'Super Robot_duplicate_4': 102,
#   'Street Racer': 8,
#   'Majestic Tiger': 2,
#   'Adorable Dogs': 10,
#   'Cozy House': 15,
#   'Sunflowers': 3,
#   'Sunflowers_duplicate_1': 60,
#   'Sunflowers_duplicate_2': 75,
#   'Sunflowers_duplicate_3': 88,
#   'Sunflowers_duplicate_4': 101,
#   'Forest Waterfall': 25,
#   'Pony-Washing Stable': 50,
#   'Pony-Washing Stable_duplicate_1': 71,
#   'Pony-Washing Stable_duplicate_2': 84,
#   'Pony-Washing Stable_duplicate_3': 97,
#   'Pony-Washing Stable_duplicate_4': 110,
#   'Pet Adoption Café': 51,
#   'Heartlake City Pizzeria': 52,
#   'Heartlake City Pizzeria_duplicate_1': 72,
#   'Heartlake City Pizzeria_duplicate_2': 85,
#   'Heartlake City Pizzeria_duplicate_3': 98,
#   'Heartlake City Pizzeria_duplicate_4': 111,
#   'Ice-Cream Truck': 53,
#   'Telehandler': 42,
#   'Telehandler_duplicate_1': 69,
#   'Telehandler_duplicate_2': 82,
#   'Telehandler_duplicate_3': 95,
#   'Telehandler_duplicate_4': 108,
#   'Material Handler': 13,
#   'Dump Truck': 27,
#   'Dump Truck_duplicate_1': 65,
#   'Dump Truck_duplicate_2': 79,
#   'Dump Truck_duplicate_3': 92,
#   'Dump Truck_duplicate_4': 105,
#   "Anna and Olaf's Castle Fun": 43,
#   'Jasmine and Mulan’s Adventure': 54,
#   'Space Ride Amusement Truck': 44,
#   'Police Mobile Command Truck': 34,
#   'Police Chase at the Bank': 45,
#   'Wild Animal Rescue Missions': 46,
#   'Cyber Stunt Bike': 59,
#   'Cyber Stunt Bike_duplicate_1': 74,
#   'Cyber Stunt Bike_duplicate_2': 87,
#   'Cyber Stunt Bike_duplicate_3': 100,
#   'Cyber Stunt Bike_duplicate_4': 113,
#   'ATV and Otter Habitat': 47,
#   'ATV and Otter Habitat_duplicate_1': 70,
#   'ATV and Otter Habitat_duplicate_2': 83,
#   'ATV and Otter Habitat_duplicate_3': 96,
#   'ATV and Otter Habitat_duplicate_4': 109,
#   'ATV and Otter Habitat_duplicate_5': 115,
#   'ATV and Otter Habitat_duplicate_6': 117,
#   'ATV and Otter Habitat_duplicate_7': 119,
#   'ATV and Otter Habitat_duplicate_8': 121,
#   'ATV and Otter Habitat_duplicate_9': 123,
#   'Ninja Dragon Temple': 28,
#   'Lloyd’s Legendary Dragon': 4,
#   "Jay's Golden Dragon Motorbike": 19,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 62,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 77,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 90,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 103,
#   'Cole’s Dragon Cruiser': 17,
#   'Boba Fett’s Starship™': 6,
#   'Hoth™ AT-ST™': 7,
#   'Dark Trooper™ Attack': 48,
#   'Death Star™ Trench Run Diorama': 16,
#   'AT-ST™': 55,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 35,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 49,
#   'Batmobile™: The Penguin™ Chase': 30,
#   "Shuri's Lab": 57,
#   "Shuri's Lab_duplicate_1": 73,
#   "Shuri's Lab_duplicate_2": 86,
#   "Shuri's Lab_duplicate_3": 99,
#   "Shuri's Lab_duplicate_4": 112,
#   'King Namor’s Throne Room': 18,
#   'Batman™ versus Harley Quinn™': 58,
#   'Hogwarts™: Polyjuice Potion Mistake': 37,
#   'Hogwarts™ Magical Trunk': 23,
#   'Hogwarts™ Carriage and Thestrals': 38,
#   '007 Aston Martin DB5': 11,
#   'Fast & Furious 1970 Dodge Charger R/T': 20,
#   'T. rex Dinosaur Breakout': 56,
#   'T. rex & Atrociraptor Dinosaur Breakout': 36,
#   'Evil Macaque’s Mech': 12,
#   'Dragon of the East': 5},
#  'Margit': {'Flower Bouquet': 21,
#   'Wildflower Bouquet': 11,
#   'Creative Transparent Bricks': 31,
#   'Creative Transparent Bricks_duplicate_1': 61,
#   'Bricks and Functions': 37,
#   'Bricks and Functions_duplicate_1': 64,
#   'Creative Monkey Fun': 48,
#   'Creative Monkey Fun_duplicate_1': 66,
#   'Creative Monkey Fun_duplicate_2': 79,
#   'Creative Monkey Fun_duplicate_3': 92,
#   'Creative Monkey Fun_duplicate_4': 105,
#   'Statue of Liberty': 2,
#   'Singapore': 5,
#   'The "Abandoned" Mine': 51,
#   'The Ruined Portal': 40,
#   'The Nether Bastion': 46,
#   'Sonic the Hedgehog™ – Green Hill Zone': 4,
#   'Cyber Drone': 57,
#   'Cyber Drone_duplicate_1': 72,
#   'Cyber Drone_duplicate_2': 85,
#   'Cyber Drone_duplicate_3': 98,
#   'Cyber Drone_duplicate_4': 111,
#   'Surfer Beach House': 10,
#   'Off-road Buggy': 58,
#   'Off-road Buggy_duplicate_1': 73,
#   'Off-road Buggy_duplicate_2': 86,
#   'Off-road Buggy_duplicate_3': 99,
#   'Off-road Buggy_duplicate_4': 112,
#   'Off-road Buggy_duplicate_5': 115,
#   'Off-road Buggy_duplicate_6': 117,
#   'Off-road Buggy_duplicate_7': 119,
#   'Off-road Buggy_duplicate_8': 121,
#   'Off-road Buggy_duplicate_9': 123,
#   'Super Robot': 54,
#   'Super Robot_duplicate_1': 70,
#   'Super Robot_duplicate_2': 83,
#   'Super Robot_duplicate_3': 96,
#   'Super Robot_duplicate_4': 109,
#   'Street Racer': 39,
#   'Majestic Tiger': 9,
#   'Adorable Dogs': 18,
#   'Cozy House': 13,
#   'Sunflowers': 42,
#   'Sunflowers_duplicate_1': 65,
#   'Sunflowers_duplicate_2': 78,
#   'Sunflowers_duplicate_3': 91,
#   'Sunflowers_duplicate_4': 104,
#   'Forest Waterfall': 41,
#   'Pony-Washing Stable': 49,
#   'Pony-Washing Stable_duplicate_1': 67,
#   'Pony-Washing Stable_duplicate_2': 80,
#   'Pony-Washing Stable_duplicate_3': 93,
#   'Pony-Washing Stable_duplicate_4': 106,
#   'Pet Adoption Café': 15,
#   'Heartlake City Pizzeria': 53,
#   'Heartlake City Pizzeria_duplicate_1': 69,
#   'Heartlake City Pizzeria_duplicate_2': 82,
#   'Heartlake City Pizzeria_duplicate_3': 95,
#   'Heartlake City Pizzeria_duplicate_4': 108,
#   'Ice-Cream Truck': 43,
#   'Telehandler': 36,
#   'Telehandler_duplicate_1': 63,
#   'Telehandler_duplicate_2': 77,
#   'Telehandler_duplicate_3': 90,
#   'Telehandler_duplicate_4': 103,
#   'Material Handler': 1,
#   'Dump Truck': 50,
#   'Dump Truck_duplicate_1': 68,
#   'Dump Truck_duplicate_2': 81,
#   'Dump Truck_duplicate_3': 94,
#   'Dump Truck_duplicate_4': 107,
#   "Anna and Olaf's Castle Fun": 30,
#   'Jasmine and Mulan’s Adventure': 22,
#   'Space Ride Amusement Truck': 6,
#   'Police Mobile Command Truck': 32,
#   'Police Chase at the Bank': 26,
#   'Wild Animal Rescue Missions': 16,
#   'Cyber Stunt Bike': 55,
#   'Cyber Stunt Bike_duplicate_1': 71,
#   'Cyber Stunt Bike_duplicate_2': 84,
#   'Cyber Stunt Bike_duplicate_3': 97,
#   'Cyber Stunt Bike_duplicate_4': 110,
#   'ATV and Otter Habitat': 34,
#   'ATV and Otter Habitat_duplicate_1': 62,
#   'ATV and Otter Habitat_duplicate_2': 76,
#   'ATV and Otter Habitat_duplicate_3': 89,
#   'ATV and Otter Habitat_duplicate_4': 102,
#   'ATV and Otter Habitat_duplicate_5': 114,
#   'ATV and Otter Habitat_duplicate_6': 116,
#   'ATV and Otter Habitat_duplicate_7': 118,
#   'ATV and Otter Habitat_duplicate_8': 120,
#   'ATV and Otter Habitat_duplicate_9': 122,
#   'Ninja Dragon Temple': 27,
#   'Lloyd’s Legendary Dragon': 3,
#   "Jay's Golden Dragon Motorbike": 23,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 60,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 75,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 88,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 101,
#   'Cole’s Dragon Cruiser': 28,
#   'Boba Fett’s Starship™': 29,
#   'Hoth™ AT-ST™': 25,
#   'Dark Trooper™ Attack': 45,
#   'Death Star™ Trench Run Diorama': 12,
#   'AT-ST™': 17,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 20,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 24,
#   'Batmobile™: The Penguin™ Chase': 19,
#   "Shuri's Lab": 59,
#   "Shuri's Lab_duplicate_1": 74,
#   "Shuri's Lab_duplicate_2": 87,
#   "Shuri's Lab_duplicate_3": 100,
#   "Shuri's Lab_duplicate_4": 113,
#   'King Namor’s Throne Room': 33,
#   'Batman™ versus Harley Quinn™': 38,
#   'Hogwarts™: Polyjuice Potion Mistake': 56,
#   'Hogwarts™ Magical Trunk': 47,
#   'Hogwarts™ Carriage and Thestrals': 44,
#   '007 Aston Martin DB5': 52,
#   'Fast & Furious 1970 Dodge Charger R/T': 35,
#   'T. rex Dinosaur Breakout': 14,
#   'T. rex & Atrociraptor Dinosaur Breakout': 7,
#   'Evil Macaque’s Mech': 8,
#   'Dragon of the East': 0},
#  'MSEP': {'Flower Bouquet': 1,
#   'Wildflower Bouquet': 2,
#   'Creative Transparent Bricks': 52,
#   'Creative Transparent Bricks_duplicate_1': 70,
#   'Bricks and Functions': 53,
#   'Bricks and Functions_duplicate_1': 71,
#   'Creative Monkey Fun': 54,
#   'Creative Monkey Fun_duplicate_1': 72,
#   'Creative Monkey Fun_duplicate_2': 85,
#   'Creative Monkey Fun_duplicate_3': 98,
#   'Creative Monkey Fun_duplicate_4': 111,
#   'Statue of Liberty': 32,
#   'Singapore': 55,
#   'The "Abandoned" Mine': 48,
#   'The Ruined Portal': 46,
#   'The Nether Bastion': 45,
#   'Sonic the Hedgehog™ – Green Hill Zone': 44,
#   'Cyber Drone': 33,
#   'Cyber Drone_duplicate_1': 65,
#   'Cyber Drone_duplicate_2': 80,
#   'Cyber Drone_duplicate_3': 93,
#   'Cyber Drone_duplicate_4': 106,
#   'Surfer Beach House': 20,
#   'Off-road Buggy': 34,
#   'Off-road Buggy_duplicate_1': 66,
#   'Off-road Buggy_duplicate_2': 81,
#   'Off-road Buggy_duplicate_3': 94,
#   'Off-road Buggy_duplicate_4': 107,
#   'Off-road Buggy_duplicate_5': 115,
#   'Off-road Buggy_duplicate_6': 117,
#   'Off-road Buggy_duplicate_7': 119,
#   'Off-road Buggy_duplicate_8': 121,
#   'Off-road Buggy_duplicate_9': 123,
#   'Super Robot': 56,
#   'Super Robot_duplicate_1': 73,
#   'Super Robot_duplicate_2': 86,
#   'Super Robot_duplicate_3': 99,
#   'Super Robot_duplicate_4': 112,
#   'Street Racer': 35,
#   'Majestic Tiger': 3,
#   'Adorable Dogs': 13,
#   'Cozy House': 4,
#   'Sunflowers': 21,
#   'Sunflowers_duplicate_1': 61,
#   'Sunflowers_duplicate_2': 76,
#   'Sunflowers_duplicate_3': 89,
#   'Sunflowers_duplicate_4': 102,
#   'Forest Waterfall': 38,
#   'Pony-Washing Stable': 39,
#   'Pony-Washing Stable_duplicate_1': 68,
#   'Pony-Washing Stable_duplicate_2': 83,
#   'Pony-Washing Stable_duplicate_3': 96,
#   'Pony-Washing Stable_duplicate_4': 109,
#   'Pet Adoption Café': 40,
#   'Heartlake City Pizzeria': 36,
#   'Heartlake City Pizzeria_duplicate_1': 67,
#   'Heartlake City Pizzeria_duplicate_2': 82,
#   'Heartlake City Pizzeria_duplicate_3': 95,
#   'Heartlake City Pizzeria_duplicate_4': 108,
#   'Ice-Cream Truck': 37,
#   'Telehandler': 23,
#   'Telehandler_duplicate_1': 63,
#   'Telehandler_duplicate_2': 78,
#   'Telehandler_duplicate_3': 91,
#   'Telehandler_duplicate_4': 104,
#   'Material Handler': 0,
#   'Dump Truck': 22,
#   'Dump Truck_duplicate_1': 62,
#   'Dump Truck_duplicate_2': 77,
#   'Dump Truck_duplicate_3': 90,
#   'Dump Truck_duplicate_4': 103,
#   "Anna and Olaf's Castle Fun": 49,
#   'Jasmine and Mulan’s Adventure': 50,
#   'Space Ride Amusement Truck': 12,
#   'Police Mobile Command Truck': 19,
#   'Police Chase at the Bank': 18,
#   'Wild Animal Rescue Missions': 17,
#   'Cyber Stunt Bike': 43,
#   'Cyber Stunt Bike_duplicate_1': 69,
#   'Cyber Stunt Bike_duplicate_2': 84,
#   'Cyber Stunt Bike_duplicate_3': 97,
#   'Cyber Stunt Bike_duplicate_4': 110,
#   'ATV and Otter Habitat': 31,
#   'ATV and Otter Habitat_duplicate_1': 64,
#   'ATV and Otter Habitat_duplicate_2': 79,
#   'ATV and Otter Habitat_duplicate_3': 92,
#   'ATV and Otter Habitat_duplicate_4': 105,
#   'ATV and Otter Habitat_duplicate_5': 114,
#   'ATV and Otter Habitat_duplicate_6': 116,
#   'ATV and Otter Habitat_duplicate_7': 118,
#   'ATV and Otter Habitat_duplicate_8': 120,
#   'ATV and Otter Habitat_duplicate_9': 122,
#   'Ninja Dragon Temple': 51,
#   'Lloyd’s Legendary Dragon': 7,
#   "Jay's Golden Dragon Motorbike": 11,
#   "Jay's Golden Dragon Motorbike_duplicate_1": 60,
#   "Jay's Golden Dragon Motorbike_duplicate_2": 75,
#   "Jay's Golden Dragon Motorbike_duplicate_3": 88,
#   "Jay's Golden Dragon Motorbike_duplicate_4": 101,
#   'Cole’s Dragon Cruiser': 8,
#   'Boba Fett’s Starship™': 9,
#   'Hoth™ AT-ST™': 10,
#   'Dark Trooper™ Attack': 42,
#   'Death Star™ Trench Run Diorama': 16,
#   'AT-ST™': 47,
#   'Obi-Wan Kenobi’s Jedi Starfighter™': 30,
#   'Obi-Wan Kenobi™ vs. Darth Vader™': 29,
#   'Batmobile™: The Penguin™ Chase': 28,
#   "Shuri's Lab": 59,
#   "Shuri's Lab_duplicate_1": 74,
#   "Shuri's Lab_duplicate_2": 87,
#   "Shuri's Lab_duplicate_3": 100,
#   "Shuri's Lab_duplicate_4": 113,
#   'King Namor’s Throne Room': 58,
#   'Batman™ versus Harley Quinn™': 57,
#   'Hogwarts™: Polyjuice Potion Mistake': 27,
#   'Hogwarts™ Magical Trunk': 26,
#   'Hogwarts™ Carriage and Thestrals': 41,
#   '007 Aston Martin DB5': 25,
#   'Fast & Furious 1970 Dodge Charger R/T': 24,
#   'T. rex Dinosaur Breakout': 15,
#   'T. rex & Atrociraptor Dinosaur Breakout': 14,
#   'Evil Macaque’s Mech': 6,
#   'Dragon of the East': 5}}

# %%
matching = MatchingGenerator.generate_matching(ranks, strategy='RMA')
matching
# Out:
# {'Black Six': ['Sunflowers',
#   'Dark Trooper™ Attack',
#   'Obi-Wan Kenobi’s Jedi Starfighter™',
#   'Ice-Cream Truck',
#   'Heartlake City Pizzeria_duplicate_1',
#   'Pony-Washing Stable_duplicate_2',
#   "Shuri's Lab_duplicate_4"],
#  'Primus': ['Fast & Furious 1970 Dodge Charger R/T',
#   '007 Aston Martin DB5',
#   "Shuri's Lab_duplicate_3",
#   "Shuri's Lab",
#   'Off-road Buggy_duplicate_1',
#   'Off-road Buggy_duplicate_3',
#   'Off-road Buggy_duplicate_4'],
#  'The Underscored Double': ['Lloyd’s Legendary Dragon',
#   'Surfer Beach House',
#   'Off-road Buggy',
#   'Sunflowers_duplicate_1',
#   'Creative Monkey Fun_duplicate_2',
#   'Sunflowers_duplicate_2',
#   'Off-road Buggy_duplicate_5'],
#  'Thundra': ['Cole’s Dragon Cruiser',
#   'King Namor’s Throne Room',
#   'Hogwarts™ Carriage and Thestrals',
#   'Off-road Buggy_duplicate_2',
#   'Super Robot_duplicate_1',
#   'Super Robot_duplicate_2',
#   'Super Robot_duplicate_3'],
#  'CareCreations': ['Telehandler',
#   'Boba Fett’s Starship™',
#   'The Nether Bastion',
#   "Anna and Olaf's Castle Fun",
#   'Telehandler_duplicate_1',
#   'Telehandler_duplicate_2',
#   'Telehandler_duplicate_3'],
#  'Calcifer': ['Sonic the Hedgehog™ – Green Hill Zone',
#   'Super Robot',
#   'Batmobile™: The Penguin™ Chase',
#   'ATV and Otter Habitat_duplicate_9',
#   'Dump Truck_duplicate_3',
#   'Off-road Buggy_duplicate_8',
#   'ATV and Otter Habitat_duplicate_6'],
#  'Kraata Kink': ['T. rex & Atrociraptor Dinosaur Breakout',
#   'T. rex Dinosaur Breakout',
#   'The "Abandoned" Mine',
#   'Pony-Washing Stable',
#   'Creative Monkey Fun_duplicate_1',
#   'Sunflowers_duplicate_3',
#   'Creative Monkey Fun_duplicate_3'],
#  'Kanakalackin': ['Ninja Dragon Temple',
#   'Cyber Drone',
#   'Creative Monkey Fun',
#   'Super Robot_duplicate_4',
#   'Cyber Drone_duplicate_1',
#   'Cyber Drone_duplicate_2',
#   'Off-road Buggy_duplicate_7'],
#  'Steve the Squid': ['Dragon of the East',
#   'Space Ride Amusement Truck',
#   'ATV and Otter Habitat_duplicate_5',
#   'Cyber Drone_duplicate_3',
#   'Bricks and Functions_duplicate_1',
#   "Jay's Golden Dragon Motorbike_duplicate_2",
#   'Telehandler_duplicate_4'],
#  'ChocolateFrogs': ['Cozy House',
#   'Death Star™ Trench Run Diorama',
#   'The Ruined Portal',
#   'Heartlake City Pizzeria_duplicate_2',
#   'Cyber Drone_duplicate_4',
#   'ATV and Otter Habitat_duplicate_3',
#   "Jay's Golden Dragon Motorbike_duplicate_4"],
#  'Ta-metru_defender': ['Hoth™ AT-ST™',
#   'Obi-Wan Kenobi™ vs. Darth Vader™',
#   'Hogwarts™ Magical Trunk',
#   'Jasmine and Mulan’s Adventure',
#   "Shuri's Lab_duplicate_1",
#   'ATV and Otter Habitat_duplicate_2',
#   'ATV and Otter Habitat_duplicate_4'],
#  'TuragaNuva': ['Evil Macaque’s Mech',
#   'Wild Animal Rescue Missions',
#   'ATV and Otter Habitat',
#   'Pony-Washing Stable_duplicate_1',
#   'ATV and Otter Habitat_duplicate_1',
#   'Cyber Stunt Bike_duplicate_4',
#   'ATV and Otter Habitat_duplicate_8'],
#  'Bionic_': ['Dump Truck',
#   "Jay's Golden Dragon Motorbike",
#   'AT-ST™',
#   'Batman™ versus Harley Quinn™',
#   'Dump Truck_duplicate_1',
#   'Dump Truck_duplicate_2',
#   'Dump Truck_duplicate_4'],
#  'Lord Oblivion': ['Wildflower Bouquet',
#   'Creative Transparent Bricks',
#   'Bricks and Functions',
#   'Off-road Buggy_duplicate_6',
#   "Jay's Golden Dragon Motorbike_duplicate_1",
#   'ATV and Otter Habitat_duplicate_7',
#   "Jay's Golden Dragon Motorbike_duplicate_3"],
#  'Kitsua': ['Material Handler',
#   'Police Chase at the Bank',
#   'Police Mobile Command Truck',
#   'Cyber Stunt Bike',
#   'Cyber Stunt Bike_duplicate_1',
#   'Cyber Stunt Bike_duplicate_2',
#   'Cyber Stunt Bike_duplicate_3'],
#  'alex_mocs': ['Flower Bouquet',
#   'Street Racer',
#   'Forest Waterfall',
#   'Creative Transparent Bricks_duplicate_1',
#   'Heartlake City Pizzeria_duplicate_3',
#   'Creative Monkey Fun_duplicate_4',
#   'Off-road Buggy_duplicate_9'],
#  'Margit': ['Statue of Liberty',
#   'Singapore',
#   'Pet Adoption Café',
#   'Pony-Washing Stable_duplicate_4',
#   "Shuri's Lab_duplicate_2",
#   'Sunflowers_duplicate_4'],
#  'MSEP': ['Majestic Tiger',
#   'Adorable Dogs',
#   'Hogwarts™: Polyjuice Potion Mistake',
#   'Heartlake City Pizzeria',
#   'Heartlake City Pizzeria_duplicate_4',
#   'Pony-Washing Stable_duplicate_3']}

# %%
profile = Profile.compute_profile_from_result(ranks, matching)
readable_profile = {i+1: profile[i] for i in range(len(profile)) if profile[i] != 0}
readable_profile
# Out:
# {1: 8,
#  2: 5,
#  3: 5,
#  4: 7,
#  5: 5,
#  6: 1,
#  7: 1,
#  8: 1,
#  9: 3,
#  11: 1,
#  12: 2,
#  13: 2,
#  14: 2,
#  15: 2,
#  16: 3,
#  17: 1,
#  19: 1,
#  22: 2,
#  23: 1,
#  26: 1,
#  27: 1,
#  28: 1,
#  31: 1,
#  33: 1,
#  37: 1,
#  47: 1,
#  61: 9,
#  62: 3,
#  65: 1,
#  68: 1,
#  73: 1,
#  76: 7,
#  77: 1,
#  78: 1,
#  83: 2,
#  84: 1,
#  88: 1,
#  89: 5,
#  90: 1,
#  93: 2,
#  94: 2,
#  96: 1,
#  97: 1,
#  99: 1,
#  102: 4,
#  103: 1,
#  104: 1,
#  105: 3,
#  107: 1,
#  108: 1,
#  109: 1,
#  111: 1,
#  115: 1,
#  116: 1,
#  117: 2,
#  119: 1,
#  120: 1,
#  121: 1,
#  122: 1,
#  123: 2}

# %%
plot = sns.barplot(x=list(readable_profile.keys()), y=list(readable_profile.values()))

plot.set_xticklabels(plot.get_xticklabels(), rotation=90, fontsize=8)
plot
# Out:
# <Axes: >

# %%
with open('matching.json', 'w+') as f:
    f.write(json.dumps(matching, indent=2))

# %%
with open('ranks.json', 'w+') as f:
    for applicant in ranks:
        for job in ranks[applicant]:
            ranks[applicant][job] = int(ranks[applicant][job])
    
    f.write(json.dumps(ranks, indent=2))
